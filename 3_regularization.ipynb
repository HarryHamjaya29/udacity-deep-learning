# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3
# ------------
#
# Previously in `2_fullyconnected.ipynb`, you trained a logistic regression and a neural network model.
#
# The goal of this assignment is to explore regularization techniques.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle

# my additional imports
import timeit

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'notMNIST.pickle'
sanitized_pickle_file = 'notMNIST_sanitized.pickle' # additional work (it includes cleaned test and valid datasets)

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape, '\n')

with open(sanitized_pickle_file, 'rb') as f:
  save = pickle.load(f)
  sanit_valid_dataset = save['valid_dataset']
  sanit_valid_labels = save['valid_labels']
  sanit_test_dataset = save['test_dataset']
  sanit_test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('sanit_Validation set', sanit_valid_dataset.shape, sanit_valid_labels.shape)
  print('sanit_Test set', sanit_test_dataset.shape, sanit_test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)
#
# sanit_Validation set (8984, 28, 28) (8984,)
# sanit_Test set (8709, 28, 28) (8709,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 1 to [0.0, 1.0, 0.0 ...], 2 to [0.0, 0.0, 1.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

sanit_valid_dataset, sanit_valid_labels = reformat(sanit_valid_dataset, sanit_valid_labels)
sanit_test_dataset, sanit_test_labels = reformat(sanit_test_dataset, sanit_test_labels)

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape, '\n')

print('sanit_Validation set', sanit_valid_dataset.shape, sanit_valid_labels.shape)
print('sanit_Test set', sanit_test_dataset.shape, sanit_test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)
#
# sanit_Validation set (8984, 784) (8984, 10)
# sanit_Test set (8709, 784) (8709, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Introduce and tune L2 regularization for both logistic and neural network models. Remember that L2 amounts to adding a penalty on the norm of the weights to the loss. In TensorFlow, you can compute the L2 loss for a tensor `t` using `nn.l2_loss(t)`. The right amount of regularization should improve your validation / test accuracy.
#
# ---

# %% [markdown]
# ## Solution 1
#
# ### Logistic regression

# %% [markdown]
# First the graph for logistic regression

# %%
batch_size = 128
L2_reg = 0.005 # ratio for L2 regularization

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  weights = tf.Variable(
    tf.truncated_normal([image_size * image_size, num_labels]))
  biases = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  logits = tf.matmul(tf_train_dataset, weights) + biases
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits)
    + L2_reg * tf.nn.l2_loss(weights))
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.1).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(
    tf.matmul(tf_valid_dataset, weights) + biases)
  test_prediction = tf.nn.softmax(tf.matmul(tf_test_dataset, weights) + biases)

# %% [markdown]
# And the optimization part for logistic regression

# %%
num_steps = 8001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print("Initialized")
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 32.426292
# Minibatch accuracy: 9.4%
# Validation accuracy: 8.1%
# Minibatch loss at step 500: 10.458254
# Minibatch accuracy: 69.5%
# Validation accuracy: 72.6%
# Minibatch loss at step 1000: 6.708092
# Minibatch accuracy: 76.6%
# Validation accuracy: 75.4%
# Minibatch loss at step 1500: 3.944610
# Minibatch accuracy: 73.4%
# Validation accuracy: 77.5%
# Minibatch loss at step 2000: 2.424660
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.2%
# Minibatch loss at step 2500: 1.748458
# Minibatch accuracy: 82.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 3000: 1.347484
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 3500: 1.001347
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.1%
# Minibatch loss at step 4000: 0.867111
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 4500: 0.654794
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 5000: 0.804653
# Minibatch accuracy: 80.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 5500: 0.620882
# Minibatch accuracy: 86.7%
# Validation accuracy: 82.8%
# Minibatch loss at step 6000: 0.646927
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 6500: 0.625350
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.7%
# Minibatch loss at step 7000: 0.705988
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.7%
# Minibatch loss at step 7500: 0.617709
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 8000: 0.813872
# Minibatch accuracy: 80.5%
# Validation accuracy: 82.7%
# Test accuracy: 89.4%

# %% [markdown]
# ### The Neural Network
#
# Graph for neural network

# %%
n_hidden = 1024 # Number of hidden nodes
batch_size = 128
L2_reg = 0.001 # ratio for L2 regularization

g = tf.Graph()
with g.as_default():
    
    # Placehodlers for training dataset minibatches
    tf_train_dataset = tf.placeholder(np.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(np.float32, shape=(batch_size, num_labels))
    
    # Constants for validation and test datasets
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Define Weights and biases as variables for hidden layer
    W_1 = tf.Variable(
        tf.truncated_normal([image_size * image_size, n_hidden])
    )
    b_1 = tf.Variable(tf.zeros([n_hidden]))
    
    # Define Weights and biases as variables for logistic regression layer
    W_0 = tf.Variable(
        tf.truncated_normal([n_hidden, num_labels]))
    b_0 = tf.Variable(tf.zeros([num_labels]))
    
    logits_1 = tf.nn.relu(tf.matmul(tf_train_dataset, W_1) + b_1) # shape will be (batch_size, n_hidden)
    
    logits_0 = tf.matmul(logits_1, W_0) + b_0 # now the shape is (batch_size, num_labels)
    
    loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits_0)
            + L2_reg * (tf.nn.l2_loss(W_0) + tf.nn.l2_loss(W_1)))
    
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
    
    # Predictions
    train_prediction = tf.nn.softmax(logits_0)
    valid_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, W_1) + b_1), W_0) + b_0)
    test_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, W_1) + b_1), W_0) + b_0)

# %% [markdown]
# And optimize the neural network

# %%
n_steps = 5001 # number of steps to be taken

with tf.Session(graph=g) as sess:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(n_steps):
        
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        
        # Prepare minibatch data
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = sess.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch  train and validation accuracy: %.1f%%, %.1f%%" 
                % (accuracy(predictions, batch_labels), 
                accuracy(valid_prediction.eval(), valid_labels)))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 652.911011
# Minibatch  train and validation accuracy: 10.2%, 29.7%
# Minibatch loss at step 500: 194.107559
# Minibatch  train and validation accuracy: 77.3%, 80.1%
# Minibatch loss at step 1000: 115.058029
# Minibatch  train and validation accuracy: 82.8%, 81.6%
# Minibatch loss at step 1500: 69.195892
# Minibatch  train and validation accuracy: 80.5%, 82.5%
# Minibatch loss at step 2000: 41.897491
# Minibatch  train and validation accuracy: 83.6%, 84.3%
# Minibatch loss at step 2500: 25.331303
# Minibatch  train and validation accuracy: 89.1%, 85.9%
# Minibatch loss at step 3000: 15.448248
# Minibatch  train and validation accuracy: 87.5%, 86.3%
# Minibatch loss at step 3500: 9.673589
# Minibatch  train and validation accuracy: 88.3%, 87.0%
# Minibatch loss at step 4000: 5.992871
# Minibatch  train and validation accuracy: 88.3%, 87.0%
# Minibatch loss at step 4500: 3.769463
# Minibatch  train and validation accuracy: 89.1%, 87.5%
# Minibatch loss at step 5000: 2.547562
# Minibatch  train and validation accuracy: 89.1%, 87.8%
# Test accuracy: 94.2%

# %% [markdown]
# ---
# Problem 2
# ---------
# Let's demonstrate an extreme case of overfitting. Restrict your training data to just a few batches. What happens?
#
# ---

# %% [markdown]
# ## Solution 2

# %%
n_hidden = 1024 # Number of hidden nodes
batch_size = 128
L2_reg = 0.000 # ratio for L2 regularization (use no regularization here)

g = tf.Graph()
with g.as_default():
    
    # Placehodlers for training dataset minibatches
    tf_train_dataset = tf.placeholder(np.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(np.float32, shape=(batch_size, num_labels))
    
    # Constants for validation and test datasets
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Define Weights and biases as variables for hidden layer
    W_1 = tf.Variable(
        tf.truncated_normal([image_size * image_size, n_hidden])
    )
    b_1 = tf.Variable(tf.zeros([n_hidden]))
    
    # Define Weights and biases as variables for logistic regression layer
    W_0 = tf.Variable(
        tf.truncated_normal([n_hidden, num_labels]))
    b_0 = tf.Variable(tf.zeros([num_labels]))
    
    logits_1 = tf.nn.relu(tf.matmul(tf_train_dataset, W_1) + b_1) # shape will be (batch_size, n_hidden)
    
    logits_0 = tf.matmul(logits_1, W_0) + b_0 # now the shape is (batch_size, num_labels)
    
    loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits_0)
            + L2_reg * (tf.nn.l2_loss(W_0) + tf.nn.l2_loss(W_1)))
    
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
    
    # Predictions
    train_prediction = tf.nn.softmax(logits_0)
    valid_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, W_1) + b_1), W_0) + b_0)
    test_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, W_1) + b_1), W_0) + b_0)

# %%
n_steps = 5001 # number of steps to be taken
mod_batches = 3 # just use first a few batches over and over again

with tf.Session(graph=g) as sess:
    tf.global_variables_initializer().run()
    print('Initialibzed')
    for step in range(n_steps):
        
        offset = (step * batch_size) % (mod_batches * batch_size - batch_size) # offset changed
        
        # Prepare minibatch data
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = sess.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch  train and validation accuracy: %.1f%%, %.1f%%" 
                % (accuracy(predictions, batch_labels), 
                accuracy(valid_prediction.eval(), valid_labels)))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialibzed
# Minibatch loss at step 0: 342.359314
# Minibatch  train and validation accuracy: 7.8%, 27.7%
# Minibatch loss at step 500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Minibatch loss at step 1000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Minibatch loss at step 1500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Minibatch loss at step 2000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Minibatch loss at step 2500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Minibatch loss at step 3000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Minibatch loss at step 3500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Minibatch loss at step 4000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Minibatch loss at step 4500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Minibatch loss at step 5000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 69.3%
# Test accuracy: 75.8%

# %% [markdown]
# Model overfits to the training batches used and the test accuracy drops.

# %% [markdown]
# ---
# Problem 3
# ---------
# Introduce Dropout on the hidden layer of the neural network. Remember: Dropout should only be introduced during training, not evaluation, otherwise your evaluation results would be stochastic as well. TensorFlow provides `nn.dropout()` for that, but you have to make sure it's only inserted during training.
#
# What happens to our extreme overfitting case?
#
# ---

# %% [markdown]
# ## Slution 3
#
# Neural network with dropout applied to hidden layer

# %%
n_hidden = 1024 # Number of hidden nodes
batch_size = 128
L2_reg = 0.000 # ratio for L2 regularization (use no regularization here)

g = tf.Graph()
with g.as_default():
    
    # Placehodlers for training dataset minibatches
    tf_train_dataset = tf.placeholder(np.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(np.float32, shape=(batch_size, num_labels))
    
    # Constants for validation and test datasets
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Define Weights and biases as variables for hidden layer
    W_1 = tf.Variable(
        tf.truncated_normal([image_size * image_size, n_hidden])
    )
    b_1 = tf.Variable(tf.zeros([n_hidden]))
    
    # Define Weights and biases as variables for logistic regression layer
    W_0 = tf.Variable(
        tf.truncated_normal([n_hidden, num_labels]))
    b_0 = tf.Variable(tf.zeros([num_labels]))
    
    # with dropout applied
    logits_1 = tf.nn.relu(tf.matmul(tf_train_dataset, W_1) + b_1) # shape will be (batch_size, n_hidden)
        
    dropout_1 = tf.nn.dropout(logits_1, 0.5)
    
    logits_0 = tf.matmul(dropout_1, W_0) + b_0 # now the shape is (batch_size, num_labels)
    
    loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits_0)
            + L2_reg * (tf.nn.l2_loss(W_0) + tf.nn.l2_loss(W_1)))
    
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
    
    # Predictions
    train_prediction = tf.nn.softmax(tf.matmul(logits_1, W_0) + b_0)
    valid_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, W_1) + b_1), W_0) + b_0)
    test_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, W_1) + b_1), W_0) + b_0)

# %%
n_steps = 5001 # number of steps to be taken
mod_batches = 3 # just use first a few batches over and over again

with tf.Session(graph=g) as sess:
    tf.global_variables_initializer().run()
    print('Initialibzed')
    for step in range(n_steps):
        
        offset = (step * batch_size) % (mod_batches * batch_size - batch_size) # offset changed
        
        # Prepare minibatch data
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = sess.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        
        if (step % 500 == 0):
            print("Minibatch loss at step %d: %f" % (step, l))
            print("Minibatch  train and validation accuracy: %.1f%%, %.1f%%" 
                % (accuracy(predictions, batch_labels), 
                accuracy(valid_prediction.eval(), valid_labels)))
    print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialibzed
# Minibatch loss at step 0: 511.439087
# Minibatch  train and validation accuracy: 7.8%, 21.6%
# Minibatch loss at step 500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 73.4%
# Minibatch loss at step 1000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 73.2%
# Minibatch loss at step 1500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 73.5%
# Minibatch loss at step 2000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 73.3%
# Minibatch loss at step 2500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 73.9%
# Minibatch loss at step 3000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 73.8%
# Minibatch loss at step 3500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 73.5%
# Minibatch loss at step 4000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 74.3%
# Minibatch loss at step 4500: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 74.1%
# Minibatch loss at step 5000: 0.000000
# Minibatch  train and validation accuracy: 100.0%, 74.4%
# Test accuracy: 81.1%

# %% [markdown]
# Using dropout, for a model with few training batches, improves the test accuracy dramatically (~5.3%).

# %% [markdown]
# ---
# Problem 4
# ---------
#
# Try to get the best performance you can using a multi-layer model! The best reported test accuracy using a deep network is [97.1%](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html?showComment=1391023266211#c8758720086795711595).
#
# One avenue you can explore is to add multiple layers.
#
# Another one is to use learning rate decay:
#
#     global_step = tf.Variable(0)  # count the number of steps taken.
#     learning_rate = tf.train.exponential_decay(0.5, global_step, ...)
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
#
#  ---

# %% [markdown]
# ## Solution 4
#
# ### Solution 4.a Model with 1 hidden layer
#
# Our best test accuracy was ~94% for a network with 1 hidden layer.
#
# Let's build a neural network with 2 hidden units

# %%
n_hidden = 1024 # Number of hidden nodes
batch_size = 500
L2_reg = 0.001 # ratio for L2 regularization

g = tf.Graph()
with g.as_default():
    
    # Placehodlers for training dataset minibatches
    tf_train_dataset = tf.placeholder(np.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(np.float32, shape=(batch_size, num_labels))
    
    # Constants for validation and test datasets
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Use learning rate decay
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(0.5, global_step, 1000, 0.95, staircase=True)
    
    # Define Weights and biases as variables for hidden layer
    W_1 = tf.Variable(
        tf.truncated_normal([image_size * image_size, n_hidden])
    )
    b_1 = tf.Variable(tf.zeros([n_hidden]))
    
    # Define Weights and biases as variables for logistic regression layer
    W_0 = tf.Variable(
        tf.truncated_normal([n_hidden, num_labels]))
    b_0 = tf.Variable(tf.zeros([num_labels]))
    
    logits_1 = tf.nn.relu(tf.matmul(tf_train_dataset, W_1) + b_1) # shape will be (batch_size, n_hidden)
    
    dropout_1 = tf.nn.dropout(logits_1, 0.5)
    
    logits_0 = tf.matmul(dropout_1, W_0) + b_0 # now the shape is (batch_size, num_labels)
    
    loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits_0)
            + L2_reg * (tf.nn.l2_loss(W_0) + tf.nn.l2_loss(W_1)))
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    # Predictions
    train_prediction = tf.nn.softmax(tf.matmul(logits_1, W_0) + b_0)
    valid_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, W_1) + b_1), W_0) + b_0)
    test_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, W_1) + b_1), W_0) + b_0)

# %% [markdown]
# Let's do the optimization with early stopping

# %%
n_epochs = 200 # number of epochs

# early-stopping parameters
patience = 5000 # look as this many examples regardless
patience_increase = 2
improvement_threshold = 0.995 # a relative improvement of 
                                  # this much is considered significant
best_valid_loss = np.inf
start_time = timeit.default_timer()

n_train_batches = train_dataset.shape[0] // batch_size

valid_freq = min(n_train_batches, patience // 2)

with tf.Session(graph=g) as sess:
    tf.global_variables_initializer().run()
    print('Initialized')
    done_looping = False
    epoch = 0
    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):
            
            batch_data = \
                train_dataset[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            batch_labels = \
                train_labels[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = sess.run(
                [optimizer, loss, train_prediction], feed_dict=feed_dict)
        
            iter = (epoch - 1) * n_train_batches + minibatch_index # cumulative iteration number
        
            if (iter + 1) % valid_freq == 0:
                this_valid_loss = 1. - (accuracy(valid_prediction.eval(), valid_labels) / 100.)
            
                print("Minibatch loss at epoch %i and iter %i: %f and learning rate: %f" % 
                      (epoch, iter, l, sess.run(learning_rate)))
                print("Minibatch  train and validation accuracy: %.1f%%, %.1f%%" 
                    % (accuracy(predictions, batch_labels), 
                    accuracy(valid_prediction.eval(), valid_labels)))
            
                if this_valid_loss < best_valid_loss:
                    if this_valid_loss < best_valid_loss * improvement_threshold:
                        patience = max(patience, iter * patience_increase)
                    
                    best_valid_loss = this_valid_loss
                    
                    params = (sess.run(W_0), sess.run(b_0),
                              sess.run(W_1), sess.run(b_1))
                    
                    # save the best model
                    with open('best_model_params.pkl', 'wb') as f:
                            pickle.dump(params, f)
                    print('Model saved')
        
            if patience <= iter:
                    done_looping = True
                    break
                    
    print("Final Test accuracy: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))
    
    with open('best_model_params.pkl', 'rb') as f:
        W_0_best, b_0_best, W_1_best, b_1_best = pickle.load(f)
        
    W_0_init, b_0_init = tf.assign(W_0, W_0_best), tf.assign(b_0, b_0_best)
    W_1_init, b_1_init = tf.assign(W_1, W_1_best), tf.assign(b_1, b_1_best)
    
    sess.run([W_0_init, b_0_init, W_1_init, b_1_init])
    
    print("Test accuracy with the best model: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))

    end_time = timeit.default_timer()

    print('Total run time %.4f minutes' % ((end_time - start_time) / 60.))
# Out:
# Initialized
# Minibatch loss at epoch 1 and iter 399: 215.319443 and learning rate: 0.500000
# Minibatch  train and validation accuracy: 81.2%, 80.8%
# Model saved
# Minibatch loss at epoch 2 and iter 799: 140.936600 and learning rate: 0.500000
# Minibatch  train and validation accuracy: 78.8%, 81.4%
# Model saved
# Minibatch loss at epoch 3 and iter 1199: 94.633652 and learning rate: 0.475000
# Minibatch  train and validation accuracy: 77.4%, 81.2%
# Minibatch loss at epoch 4 and iter 1599: 63.851974 and learning rate: 0.475000
# Minibatch  train and validation accuracy: 83.0%, 83.8%
# Model saved
# Minibatch loss at epoch 5 and iter 1999: 43.597389 and learning rate: 0.451250
# Minibatch  train and validation accuracy: 83.2%, 84.6%
# Model saved
# Minibatch loss at epoch 6 and iter 2399: 30.428461 and learning rate: 0.451250
# Minibatch  train and validation accuracy: 84.2%, 85.9%
# Model saved
# Minibatch loss at epoch 7 and iter 2799: 21.329872 and learning rate: 0.451250
# Minibatch  train and validation accuracy: 86.4%, 86.2%
# Model saved
# Minibatch loss at epoch 8 and iter 3199: 15.166991 and learning rate: 0.428687
# Minibatch  train and validation accuracy: 87.4%, 86.5%
# Model saved
# Minibatch loss at epoch 9 and iter 3599: 10.924129 and learning rate: 0.428687
# Minibatch  train and validation accuracy: 88.2%, 87.0%
# Model saved
# Minibatch loss at epoch 10 and iter 3999: 7.888458 and learning rate: 0.407253
# Minibatch  train and validation accuracy: 88.8%, 87.2%
# Model saved
# Minibatch loss at epoch 11 and iter 4399: 5.827725 and learning rate: 0.407253
# Minibatch  train and validation accuracy: 88.8%, 87.5%
# Model saved
# Minibatch loss at epoch 12 and iter 4799: 4.362767 and learning rate: 0.407253
# Minibatch  train and validation accuracy: 89.2%, 87.8%
# Model saved
# Minibatch loss at epoch 13 and iter 5199: 3.314730 and learning rate: 0.386890
# Minibatch  train and validation accuracy: 89.4%, 88.0%
# Model saved
# Minibatch loss at epoch 14 and iter 5599: 2.564153 and learning rate: 0.386890
# Minibatch  train and validation accuracy: 90.0%, 88.2%
# Model saved
# Minibatch loss at epoch 15 and iter 5999: 2.021358 and learning rate: 0.367546
# Minibatch  train and validation accuracy: 89.6%, 88.4%
# Model saved
# Minibatch loss at epoch 16 and iter 6399: 1.664926 and learning rate: 0.367546
# Minibatch  train and validation accuracy: 89.6%, 88.5%
# Model saved
# Minibatch loss at epoch 17 and iter 6799: 1.352479 and learning rate: 0.367546
# Minibatch  train and validation accuracy: 90.2%, 88.6%
# Model saved
# Minibatch loss at epoch 18 and iter 7199: 1.130136 and learning rate: 0.349169
# Minibatch  train and validation accuracy: 90.2%, 88.6%
# Model saved
# Minibatch loss at epoch 19 and iter 7599: 0.976179 and learning rate: 0.349169
# Minibatch  train and validation accuracy: 90.0%, 88.7%
# Model saved
# Minibatch loss at epoch 20 and iter 7999: 0.859580 and learning rate: 0.331710
# Minibatch  train and validation accuracy: 89.8%, 88.6%
# Minibatch loss at epoch 21 and iter 8399: 0.801986 and learning rate: 0.331710
# Minibatch  train and validation accuracy: 90.2%, 88.8%
# Model saved
# Minibatch loss at epoch 22 and iter 8799: 0.726356 and learning rate: 0.331710
# Minibatch  train and validation accuracy: 90.0%, 88.8%
# Minibatch loss at epoch 23 and iter 9199: 0.667410 and learning rate: 0.315125
# Minibatch  train and validation accuracy: 90.2%, 88.8%
# Model saved
# Minibatch loss at epoch 24 and iter 9599: 0.634857 and learning rate: 0.315125
# Minibatch  train and validation accuracy: 90.2%, 88.9%
# Model saved
# Minibatch loss at epoch 25 and iter 9999: 0.592084 and learning rate: 0.299368
# Minibatch  train and validation accuracy: 90.0%, 89.0%
# Model saved
# Minibatch loss at epoch 26 and iter 10399: 0.597837 and learning rate: 0.299368
# Minibatch  train and validation accuracy: 90.0%, 89.1%
# Model saved
# Minibatch loss at epoch 27 and iter 10799: 0.555885 and learning rate: 0.299368
# Minibatch  train and validation accuracy: 90.2%, 89.0%
# Minibatch loss at epoch 28 and iter 11199: 0.552798 and learning rate: 0.284400
# Minibatch  train and validation accuracy: 90.8%, 89.0%
# Minibatch loss at epoch 29 and iter 11599: 0.539091 and learning rate: 0.284400
# Minibatch  train and validation accuracy: 90.6%, 89.1%
# Minibatch loss at epoch 30 and iter 11999: 0.523931 and learning rate: 0.270180
# Minibatch  train and validation accuracy: 90.8%, 89.1%
# Minibatch loss at epoch 31 and iter 12399: 0.511302 and learning rate: 0.270180
# Minibatch  train and validation accuracy: 91.0%, 89.0%
# Minibatch loss at epoch 32 and iter 12799: 0.503407 and learning rate: 0.270180
# Minibatch  train and validation accuracy: 91.0%, 89.1%
# Model saved
# Minibatch loss at epoch 33 and iter 13199: 0.495722 and learning rate: 0.256671
# Minibatch  train and validation accuracy: 91.2%, 89.0%
# Minibatch loss at epoch 34 and iter 13599: 0.479391 and learning rate: 0.256671
# Minibatch  train and validation accuracy: 91.2%, 89.2%
# Model saved
# Minibatch loss at epoch 35 and iter 13999: 0.501623 and learning rate: 0.243837
# Minibatch  train and validation accuracy: 90.8%, 89.1%
# Minibatch loss at epoch 36 and iter 14399: 0.501373 and learning rate: 0.243837
# Minibatch  train and validation accuracy: 91.0%, 89.2%
# Model saved
# Minibatch loss at epoch 37 and iter 14799: 0.511703 and learning rate: 0.243837
# Minibatch  train and validation accuracy: 91.2%, 89.2%
# Minibatch loss at epoch 38 and iter 15199: 0.467031 and learning rate: 0.231646
# Minibatch  train and validation accuracy: 91.2%, 89.2%
# Minibatch loss at epoch 39 and iter 15599: 0.488397 and learning rate: 0.231646
# Minibatch  train and validation accuracy: 91.0%, 89.3%
# Model saved
# Minibatch loss at epoch 40 and iter 15999: 0.481631 and learning rate: 0.220063
# Minibatch  train and validation accuracy: 91.0%, 89.4%
# Model saved
# Minibatch loss at epoch 41 and iter 16399: 0.474609 and learning rate: 0.220063
# Minibatch  train and validation accuracy: 91.0%, 89.4%
# Model saved
# Minibatch loss at epoch 42 and iter 16799: 0.499928 and learning rate: 0.220063
# Minibatch  train and validation accuracy: 91.4%, 89.3%
# Minibatch loss at epoch 43 and iter 17199: 0.470899 and learning rate: 0.209060
# Minibatch  train and validation accuracy: 90.8%, 89.5%
# Model saved
# Minibatch loss at epoch 44 and iter 17599: 0.465307 and learning rate: 0.209060
# Minibatch  train and validation accuracy: 91.6%, 89.3%
# Minibatch loss at epoch 45 and iter 17999: 0.483864 and learning rate: 0.198607
# Minibatch  train and validation accuracy: 91.6%, 89.4%
# Minibatch loss at epoch 46 and iter 18399: 0.469512 and learning rate: 0.198607
# Minibatch  train and validation accuracy: 91.4%, 89.3%
# Minibatch loss at epoch 47 and iter 18799: 0.472318 and learning rate: 0.198607
# Minibatch  train and validation accuracy: 91.6%, 89.3%
# Minibatch loss at epoch 48 and iter 19199: 0.488485 and learning rate: 0.188677
# Minibatch  train and validation accuracy: 91.6%, 89.4%
# Minibatch loss at epoch 49 and iter 19599: 0.474787 and learning rate: 0.188677
# Minibatch  train and validation accuracy: 91.2%, 89.3%
# Minibatch loss at epoch 50 and iter 19999: 0.475125 and learning rate: 0.179243
# Minibatch  train and validation accuracy: 91.0%, 89.5%
# Model saved
# Minibatch loss at epoch 51 and iter 20399: 0.477646 and learning rate: 0.179243
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 52 and iter 20799: 0.452989 and learning rate: 0.179243
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 53 and iter 21199: 0.479044 and learning rate: 0.170281
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 54 and iter 21599: 0.470838 and learning rate: 0.170281
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 55 and iter 21999: 0.461742 and learning rate: 0.161767
# Minibatch  train and validation accuracy: 91.2%, 89.4%
# Minibatch loss at epoch 56 and iter 22399: 0.468709 and learning rate: 0.161767
# Minibatch  train and validation accuracy: 91.2%, 89.4%
# Minibatch loss at epoch 57 and iter 22799: 0.453343 and learning rate: 0.161767
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 58 and iter 23199: 0.449144 and learning rate: 0.153678
# Minibatch  train and validation accuracy: 91.6%, 89.4%
# Minibatch loss at epoch 59 and iter 23599: 0.470688 and learning rate: 0.153678
# Minibatch  train and validation accuracy: 91.4%, 89.4%
# Minibatch loss at epoch 60 and iter 23999: 0.461299 and learning rate: 0.145994
# Minibatch  train and validation accuracy: 91.6%, 89.4%
# Minibatch loss at epoch 61 and iter 24399: 0.458182 and learning rate: 0.145994
# Minibatch  train and validation accuracy: 91.6%, 89.4%
# Minibatch loss at epoch 62 and iter 24799: 0.452661 and learning rate: 0.145994
# Minibatch  train and validation accuracy: 91.6%, 89.4%
# Minibatch loss at epoch 63 and iter 25199: 0.448144 and learning rate: 0.138695
# Minibatch  train and validation accuracy: 91.4%, 89.4%
# Minibatch loss at epoch 64 and iter 25599: 0.469139 and learning rate: 0.138695
# Minibatch  train and validation accuracy: 91.4%, 89.4%
# Minibatch loss at epoch 65 and iter 25999: 0.469924 and learning rate: 0.131760
# Minibatch  train and validation accuracy: 91.4%, 89.4%
# Minibatch loss at epoch 66 and iter 26399: 0.463965 and learning rate: 0.131760
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 67 and iter 26799: 0.450834 and learning rate: 0.131760
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 68 and iter 27199: 0.472635 and learning rate: 0.125172
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Model saved
# Minibatch loss at epoch 69 and iter 27599: 0.443711 and learning rate: 0.125172
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 70 and iter 27999: 0.446361 and learning rate: 0.118913
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 71 and iter 28399: 0.462630 and learning rate: 0.118913
# Minibatch  train and validation accuracy: 91.8%, 89.5%
# Minibatch loss at epoch 72 and iter 28799: 0.459858 and learning rate: 0.118913
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 73 and iter 29199: 0.465648 and learning rate: 0.112968
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 74 and iter 29599: 0.440607 and learning rate: 0.112968
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 75 and iter 29999: 0.449959 and learning rate: 0.107319
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 76 and iter 30399: 0.451668 and learning rate: 0.107319
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 77 and iter 30799: 0.443799 and learning rate: 0.107319
# Minibatch  train and validation accuracy: 91.6%, 89.4%
# Minibatch loss at epoch 78 and iter 31199: 0.452111 and learning rate: 0.101953
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 79 and iter 31599: 0.447565 and learning rate: 0.101953
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 80 and iter 31999: 0.453538 and learning rate: 0.096856
# Minibatch  train and validation accuracy: 91.4%, 89.6%
# Model saved
# Minibatch loss at epoch 81 and iter 32399: 0.455747 and learning rate: 0.096856
# Minibatch  train and validation accuracy: 91.8%, 89.6%
# Minibatch loss at epoch 82 and iter 32799: 0.445392 and learning rate: 0.096856
# Minibatch  train and validation accuracy: 91.8%, 89.6%
# Model saved
# Minibatch loss at epoch 83 and iter 33199: 0.443839 and learning rate: 0.092013
# Minibatch  train and validation accuracy: 91.8%, 89.5%
# Minibatch loss at epoch 84 and iter 33599: 0.445707 and learning rate: 0.092013
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 85 and iter 33999: 0.460071 and learning rate: 0.087412
# Minibatch  train and validation accuracy: 91.8%, 89.6%
# Model saved
# Minibatch loss at epoch 86 and iter 34399: 0.424612 and learning rate: 0.087412
# Minibatch  train and validation accuracy: 91.8%, 89.5%
# Minibatch loss at epoch 87 and iter 34799: 0.449732 and learning rate: 0.087412
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 88 and iter 35199: 0.450860 and learning rate: 0.083042
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 89 and iter 35599: 0.459730 and learning rate: 0.083042
# Minibatch  train and validation accuracy: 91.6%, 89.6%
# Minibatch loss at epoch 90 and iter 35999: 0.468089 and learning rate: 0.078890
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 91 and iter 36399: 0.463494 and learning rate: 0.078890
# Minibatch  train and validation accuracy: 91.4%, 89.6%
# Model saved
# Minibatch loss at epoch 92 and iter 36799: 0.445355 and learning rate: 0.078890
# Minibatch  train and validation accuracy: 91.4%, 89.6%
# Minibatch loss at epoch 93 and iter 37199: 0.455976 and learning rate: 0.074945
# Minibatch  train and validation accuracy: 91.6%, 89.6%
# Minibatch loss at epoch 94 and iter 37599: 0.437444 and learning rate: 0.074945
# Minibatch  train and validation accuracy: 91.6%, 89.6%
# Minibatch loss at epoch 95 and iter 37999: 0.453723 and learning rate: 0.071198
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 96 and iter 38399: 0.455439 and learning rate: 0.071198
# Minibatch  train and validation accuracy: 91.8%, 89.6%
# Model saved
# Minibatch loss at epoch 97 and iter 38799: 0.454644 and learning rate: 0.071198
# Minibatch  train and validation accuracy: 91.8%, 89.6%
# Minibatch loss at epoch 98 and iter 39199: 0.440032 and learning rate: 0.067638
# Minibatch  train and validation accuracy: 91.8%, 89.6%
# Model saved
# Minibatch loss at epoch 99 and iter 39599: 0.450762 and learning rate: 0.067638
# Minibatch  train and validation accuracy: 92.0%, 89.6%
# Final Test accuracy: 95.4%
# Test accuracy with the best model: 95.4%
# Total run time 42.2736 minutes

# %% [markdown]
# ---
# ### Solution 4.b Model with two hidden layers
#
# Now let's try a model with 2 hidden layers. Weights with truncated normal distribution won't work here, thus we will initialize the weights with [Xavier initialization](http://www.cs.cmu.edu/~bhiksha/courses/deeplearning/Fall.2016/pdfs/1111/AISTATS2010_Glorot.pdf).

# %%
n_hidden_2 = 1024 # Number of hidden nodes for hidden layer 2
n_hidden_1 = 500  # Number of hidden nodes for hidden layer 1
batch_size = 128
L2_reg = 0.000 # ratio for L2 regularization

g = tf.Graph()
with g.as_default():
    
    # Placehodlers for training dataset minibatches
    tf_train_dataset = tf.placeholder(np.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(np.float32, shape=(batch_size, num_labels))
    
    # Constants for validation and test datasets
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Use learning rate decay
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(0.05, global_step, 5000, 0.95, staircase=True)
    
    # Define Weights and biases as variables for hidden layers
    W_2 = tf.get_variable("W2", shape=[image_size * image_size, n_hidden_2],
                                initializer=tf.contrib.layers.xavier_initializer())
    b_2 = tf.Variable(tf.zeros([n_hidden_2]))
    
    W_1 = tf.get_variable("W1", shape=[n_hidden_2, n_hidden_1],
                                initializer=tf.contrib.layers.xavier_initializer())
    b_1 = tf.Variable(tf.zeros([n_hidden_1]))
    
    # Define Weights and biases as variables for logistic regression layer
    W_0 = tf.get_variable("W0", shape=[n_hidden_1, num_labels],
                                initializer=tf.contrib.layers.xavier_initializer())
    b_0 = tf.Variable(tf.zeros([num_labels]))
    
    logits_2 = tf.nn.relu(tf.matmul(tf_train_dataset, W_2) + b_2) # shape will be (batch_size, n_hidden_2)
    
    dropout_2 = tf.nn.dropout(logits_2, 0.5)
    
    logits_1 = tf.nn.relu(tf.matmul(dropout_2, W_1) + b_1) # shape will be (batch_size, n_hidden_1)
    
    dropout_1 = tf.nn.dropout(logits_1, 0.5)
    
    logits_0 = tf.matmul(dropout_1, W_0) + b_0 # now the shape is (batch_size, num_labels)
    
    loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits_0)
            + L2_reg * (tf.nn.l2_loss(W_0) + tf.nn.l2_loss(W_1) + tf.nn.l2_loss(W_2)))
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    # Predictions
    def get_logits(dataset):
        get_logits_2 = tf.nn.relu(tf.matmul(dataset, W_2) + b_2)
        get_logits_1 = tf.nn.relu(tf.matmul(get_logits_2, W_1) + b_1)
        get_logits_0 = tf.matmul(get_logits_1, W_0) + b_0
        return get_logits_0

    train_prediction = tf.nn.softmax(get_logits(tf_train_dataset))
    valid_prediction = tf.nn.softmax(get_logits(tf_valid_dataset))
    test_prediction = tf.nn.softmax(get_logits(tf_test_dataset))

# %%
n_epochs = 200 # number of epochs

# early-stopping parameters
patience = 5000 # look as this many examples regardless
patience_increase = 2
improvement_threshold = 0.995 # a relative improvement of 
                                  # this much is considered significant
best_valid_loss = np.inf
start_time = timeit.default_timer()

n_train_batches = train_dataset.shape[0] // batch_size

valid_freq = min(n_train_batches, patience // 2)

with tf.Session(graph=g) as sess:
    tf.global_variables_initializer().run()
    print('Initialized')
    done_looping = False
    epoch = 0
    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):
            
            batch_data = \
                train_dataset[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            batch_labels = \
                train_labels[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = sess.run(
                [optimizer, loss, train_prediction], feed_dict=feed_dict)
        
            iter = (epoch - 1) * n_train_batches + minibatch_index # cumulative iteration number
        
            if (iter + 1) % valid_freq == 0:
                this_valid_loss = 1. - (accuracy(valid_prediction.eval(), valid_labels) / 100.)
            
                print("Minibatch loss at epoch %i and iter %i: %f and learning rate: %f" % 
                      (epoch, iter, l, sess.run(learning_rate)))
                print("Minibatch  train and validation accuracy: %.1f%%, %.1f%%" 
                    % (accuracy(predictions, batch_labels), 
                    accuracy(valid_prediction.eval(), valid_labels)))
            
                if this_valid_loss < best_valid_loss:
                    if this_valid_loss < best_valid_loss * improvement_threshold:
                        patience = max(patience, iter * patience_increase)
                    
                    best_valid_loss = this_valid_loss
                    
                    params = (sess.run(W_0), sess.run(b_0),
                              sess.run(W_1), sess.run(b_1),
                              sess.run(W_2), sess.run(b_2))
                    
                    # save the best model
                    with open('best_model_params.pkl', 'wb') as f:
                            pickle.dump(params, f)
                    print('Model saved')
        
            if patience <= iter:
                    done_looping = True
                    break
                    
    print("Final Test accuracy: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))
    
    with open('best_model_params.pkl', 'rb') as f:
        W_0_best, b_0_best, W_1_best, b_1_best, W_2_best, b_2_best = pickle.load(f)
        
    W_0_init, b_0_init = tf.assign(W_0, W_0_best), tf.assign(b_0, b_0_best)
    W_1_init, b_1_init = tf.assign(W_1, W_1_best), tf.assign(b_1, b_1_best)
    W_2_init, b_2_init = tf.assign(W_2, W_2_best), tf.assign(b_2, b_2_best)
    
    sess.run([W_0_init, b_0_init, W_1_init, b_1_init, W_2_init, b_2_init])
    
    print("Test accuracy with the best model: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))

    end_time = timeit.default_timer()

    print('Total run time %.4f minutes' % ((end_time - start_time) / 60.))
# Out:
# Initialized
# Minibatch loss at epoch 1 and iter 1561: 0.441507 and learning rate: 0.050000
# Minibatch  train and validation accuracy: 89.1%, 84.7%
# Model saved
# Minibatch loss at epoch 2 and iter 3123: 0.406085 and learning rate: 0.050000
# Minibatch  train and validation accuracy: 90.6%, 86.0%
# Model saved
# Minibatch loss at epoch 3 and iter 4685: 0.360064 and learning rate: 0.050000
# Minibatch  train and validation accuracy: 90.6%, 86.6%
# Model saved
# Minibatch loss at epoch 4 and iter 6247: 0.351320 and learning rate: 0.047500
# Minibatch  train and validation accuracy: 91.4%, 87.4%
# Model saved
# Minibatch loss at epoch 5 and iter 7809: 0.314280 and learning rate: 0.047500
# Minibatch  train and validation accuracy: 92.2%, 87.8%
# Model saved
# Minibatch loss at epoch 6 and iter 9371: 0.299480 and learning rate: 0.047500
# Minibatch  train and validation accuracy: 92.2%, 88.1%
# Model saved
# Minibatch loss at epoch 7 and iter 10933: 0.289495 and learning rate: 0.045125
# Minibatch  train and validation accuracy: 93.0%, 88.5%
# Model saved
# Minibatch loss at epoch 8 and iter 12495: 0.271861 and learning rate: 0.045125
# Minibatch  train and validation accuracy: 93.0%, 88.5%
# Model saved
# Minibatch loss at epoch 9 and iter 14057: 0.259534 and learning rate: 0.045125
# Minibatch  train and validation accuracy: 93.0%, 88.9%
# Model saved
# Minibatch loss at epoch 10 and iter 15619: 0.280005 and learning rate: 0.042869
# Minibatch  train and validation accuracy: 93.0%, 89.1%
# Model saved
# Minibatch loss at epoch 11 and iter 17181: 0.210785 and learning rate: 0.042869
# Minibatch  train and validation accuracy: 93.0%, 89.2%
# Model saved
# Minibatch loss at epoch 12 and iter 18743: 0.236095 and learning rate: 0.042869
# Minibatch  train and validation accuracy: 93.8%, 89.3%
# Model saved
# Minibatch loss at epoch 13 and iter 20305: 0.232185 and learning rate: 0.040725
# Minibatch  train and validation accuracy: 95.3%, 89.4%
# Model saved
# Minibatch loss at epoch 14 and iter 21867: 0.235914 and learning rate: 0.040725
# Minibatch  train and validation accuracy: 95.3%, 89.6%
# Model saved
# Minibatch loss at epoch 15 and iter 23429: 0.240177 and learning rate: 0.040725
# Minibatch  train and validation accuracy: 95.3%, 89.8%
# Model saved
# Minibatch loss at epoch 16 and iter 24991: 0.198339 and learning rate: 0.040725
# Minibatch  train and validation accuracy: 95.3%, 89.7%
# Minibatch loss at epoch 17 and iter 26553: 0.219044 and learning rate: 0.038689
# Minibatch  train and validation accuracy: 95.3%, 89.8%
# Model saved
# Minibatch loss at epoch 18 and iter 28115: 0.208007 and learning rate: 0.038689
# Minibatch  train and validation accuracy: 95.3%, 89.9%
# Model saved
# Minibatch loss at epoch 19 and iter 29677: 0.237887 and learning rate: 0.038689
# Minibatch  train and validation accuracy: 95.3%, 90.0%
# Model saved
# Minibatch loss at epoch 20 and iter 31239: 0.211719 and learning rate: 0.036755
# Minibatch  train and validation accuracy: 96.1%, 90.1%
# Model saved
# Minibatch loss at epoch 21 and iter 32801: 0.179138 and learning rate: 0.036755
# Minibatch  train and validation accuracy: 95.3%, 90.1%
# Minibatch loss at epoch 22 and iter 34363: 0.173404 and learning rate: 0.036755
# Minibatch  train and validation accuracy: 96.1%, 90.4%
# Model saved
# Minibatch loss at epoch 23 and iter 35925: 0.184377 and learning rate: 0.034917
# Minibatch  train and validation accuracy: 96.1%, 90.1%
# Minibatch loss at epoch 24 and iter 37487: 0.171163 and learning rate: 0.034917
# Minibatch  train and validation accuracy: 96.1%, 90.3%
# Minibatch loss at epoch 25 and iter 39049: 0.164773 and learning rate: 0.034917
# Minibatch  train and validation accuracy: 96.1%, 90.3%
# Minibatch loss at epoch 26 and iter 40611: 0.185351 and learning rate: 0.033171
# Minibatch  train and validation accuracy: 96.1%, 90.4%
# Minibatch loss at epoch 27 and iter 42173: 0.208129 and learning rate: 0.033171
# Minibatch  train and validation accuracy: 96.1%, 90.4%
# Model saved
# Minibatch loss at epoch 28 and iter 43735: 0.183162 and learning rate: 0.033171
# Minibatch  train and validation accuracy: 96.1%, 90.4%
# Minibatch loss at epoch 29 and iter 45297: 0.149011 and learning rate: 0.031512
# Minibatch  train and validation accuracy: 96.1%, 90.4%
# Model saved
# Minibatch loss at epoch 30 and iter 46859: 0.137191 and learning rate: 0.031512
# Minibatch  train and validation accuracy: 96.1%, 90.5%
# Model saved
# Minibatch loss at epoch 31 and iter 48421: 0.162921 and learning rate: 0.031512
# Minibatch  train and validation accuracy: 96.1%, 90.5%
# Minibatch loss at epoch 32 and iter 49983: 0.136553 and learning rate: 0.031512
# Minibatch  train and validation accuracy: 96.1%, 90.5%
# Minibatch loss at epoch 33 and iter 51545: 0.178289 and learning rate: 0.029937
# Minibatch  train and validation accuracy: 96.1%, 90.5%
# Minibatch loss at epoch 34 and iter 53107: 0.174691 and learning rate: 0.029937
# Minibatch  train and validation accuracy: 96.1%, 90.6%
# Model saved
# Minibatch loss at epoch 35 and iter 54669: 0.142634 and learning rate: 0.029937
# Minibatch  train and validation accuracy: 96.1%, 90.6%
# Minibatch loss at epoch 36 and iter 56231: 0.141100 and learning rate: 0.028440
# Minibatch  train and validation accuracy: 96.1%, 90.7%
# Model saved
# Minibatch loss at epoch 37 and iter 57793: 0.123940 and learning rate: 0.028440
# Minibatch  train and validation accuracy: 96.1%, 90.6%
# Minibatch loss at epoch 38 and iter 59355: 0.187915 and learning rate: 0.028440
# Minibatch  train and validation accuracy: 96.9%, 90.7%
# Model saved
# Minibatch loss at epoch 39 and iter 60917: 0.136904 and learning rate: 0.027018
# Minibatch  train and validation accuracy: 96.1%, 90.8%
# Model saved
# Minibatch loss at epoch 40 and iter 62479: 0.136269 and learning rate: 0.027018
# Minibatch  train and validation accuracy: 96.9%, 90.8%
# Minibatch loss at epoch 41 and iter 64041: 0.128825 and learning rate: 0.027018
# Minibatch  train and validation accuracy: 96.9%, 90.8%
# Model saved
# Minibatch loss at epoch 42 and iter 65603: 0.131256 and learning rate: 0.025667
# Minibatch  train and validation accuracy: 96.1%, 90.8%
# Minibatch loss at epoch 43 and iter 67165: 0.148663 and learning rate: 0.025667
# Minibatch  train and validation accuracy: 97.7%, 90.9%
# Model saved
# Minibatch loss at epoch 44 and iter 68727: 0.124557 and learning rate: 0.025667
# Minibatch  train and validation accuracy: 96.9%, 90.9%
# Model saved
# Minibatch loss at epoch 45 and iter 70289: 0.141411 and learning rate: 0.024384
# Minibatch  train and validation accuracy: 97.7%, 90.9%
# Minibatch loss at epoch 46 and iter 71851: 0.139675 and learning rate: 0.024384
# Minibatch  train and validation accuracy: 97.7%, 91.0%
# Model saved
# Minibatch loss at epoch 47 and iter 73413: 0.128571 and learning rate: 0.024384
# Minibatch  train and validation accuracy: 97.7%, 91.0%
# Minibatch loss at epoch 48 and iter 74975: 0.116576 and learning rate: 0.024384
# Minibatch  train and validation accuracy: 98.4%, 90.9%
# Minibatch loss at epoch 49 and iter 76537: 0.109994 and learning rate: 0.023165
# Minibatch  train and validation accuracy: 99.2%, 91.0%
# Minibatch loss at epoch 50 and iter 78099: 0.116880 and learning rate: 0.023165
# Minibatch  train and validation accuracy: 98.4%, 91.0%
# Minibatch loss at epoch 51 and iter 79661: 0.118227 and learning rate: 0.023165
# Minibatch  train and validation accuracy: 99.2%, 91.0%
# Minibatch loss at epoch 52 and iter 81223: 0.102005 and learning rate: 0.022006
# Minibatch  train and validation accuracy: 98.4%, 91.1%
# Model saved
# Minibatch loss at epoch 53 and iter 82785: 0.153993 and learning rate: 0.022006
# Minibatch  train and validation accuracy: 98.4%, 91.1%
# Model saved
# Minibatch loss at epoch 54 and iter 84347: 0.137560 and learning rate: 0.022006
# Minibatch  train and validation accuracy: 98.4%, 91.0%
# Minibatch loss at epoch 55 and iter 85909: 0.096661 and learning rate: 0.020906
# Minibatch  train and validation accuracy: 99.2%, 91.0%
# Minibatch loss at epoch 56 and iter 87471: 0.183676 and learning rate: 0.020906
# Minibatch  train and validation accuracy: 99.2%, 91.0%
# Minibatch loss at epoch 57 and iter 89033: 0.090831 and learning rate: 0.020906
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Model saved
# Minibatch loss at epoch 58 and iter 90595: 0.130934 and learning rate: 0.019861
# Minibatch  train and validation accuracy: 99.2%, 91.0%
# Minibatch loss at epoch 59 and iter 92157: 0.103944 and learning rate: 0.019861
# Minibatch  train and validation accuracy: 99.2%, 91.0%
# Minibatch loss at epoch 60 and iter 93719: 0.079282 and learning rate: 0.019861
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 61 and iter 95281: 0.104421 and learning rate: 0.018868
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 62 and iter 96843: 0.139491 and learning rate: 0.018868
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 63 and iter 98405: 0.101412 and learning rate: 0.018868
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 64 and iter 99967: 0.132190 and learning rate: 0.018868
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 65 and iter 101529: 0.108443 and learning rate: 0.017924
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Model saved
# Minibatch loss at epoch 66 and iter 103091: 0.078565 and learning rate: 0.017924
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 67 and iter 104653: 0.113814 and learning rate: 0.017924
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 68 and iter 106215: 0.075246 and learning rate: 0.017028
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Model saved
# Minibatch loss at epoch 69 and iter 107777: 0.120934 and learning rate: 0.017028
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 70 and iter 109339: 0.079714 and learning rate: 0.017028
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Model saved
# Minibatch loss at epoch 71 and iter 110901: 0.149513 and learning rate: 0.016177
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 72 and iter 112463: 0.087687 and learning rate: 0.016177
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 73 and iter 114025: 0.104555 and learning rate: 0.016177
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 74 and iter 115587: 0.129033 and learning rate: 0.015368
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 75 and iter 117149: 0.115243 and learning rate: 0.015368
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Model saved
# Minibatch loss at epoch 76 and iter 118711: 0.102477 and learning rate: 0.015368
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Model saved
# Minibatch loss at epoch 77 and iter 120273: 0.103873 and learning rate: 0.014599
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Model saved
# Minibatch loss at epoch 78 and iter 121835: 0.135747 and learning rate: 0.014599
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 79 and iter 123397: 0.065613 and learning rate: 0.014599
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 80 and iter 124959: 0.132929 and learning rate: 0.014599
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 81 and iter 126521: 0.137461 and learning rate: 0.013869
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 82 and iter 128083: 0.086893 and learning rate: 0.013869
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 83 and iter 129645: 0.099543 and learning rate: 0.013869
# Minibatch  train and validation accuracy: 99.2%, 91.1%
# Minibatch loss at epoch 84 and iter 131207: 0.097668 and learning rate: 0.013176
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 85 and iter 132769: 0.124513 and learning rate: 0.013176
# Minibatch  train and validation accuracy: 100.0%, 91.1%
# Minibatch loss at epoch 86 and iter 134331: 0.111546 and learning rate: 0.013176
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 87 and iter 135893: 0.122374 and learning rate: 0.012517
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 88 and iter 137455: 0.113752 and learning rate: 0.012517
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 89 and iter 139017: 0.122144 and learning rate: 0.012517
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 90 and iter 140579: 0.107156 and learning rate: 0.011891
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 91 and iter 142141: 0.089402 and learning rate: 0.011891
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 92 and iter 143703: 0.115727 and learning rate: 0.011891
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 93 and iter 145265: 0.091251 and learning rate: 0.011297
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 94 and iter 146827: 0.063686 and learning rate: 0.011297
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 95 and iter 148389: 0.083986 and learning rate: 0.011297
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 96 and iter 149951: 0.072582 and learning rate: 0.011297
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 97 and iter 151513: 0.093222 and learning rate: 0.010732
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 98 and iter 153075: 0.120205 and learning rate: 0.010732
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 99 and iter 154637: 0.075712 and learning rate: 0.010732
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 100 and iter 156199: 0.112780 and learning rate: 0.010195
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Model saved
# Minibatch loss at epoch 101 and iter 157761: 0.050195 and learning rate: 0.010195
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 102 and iter 159323: 0.082334 and learning rate: 0.010195
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 103 and iter 160885: 0.095912 and learning rate: 0.009686
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 104 and iter 162447: 0.084512 and learning rate: 0.009686
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 105 and iter 164009: 0.060415 and learning rate: 0.009686
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 106 and iter 165571: 0.111641 and learning rate: 0.009201
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 107 and iter 167133: 0.092529 and learning rate: 0.009201
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 108 and iter 168695: 0.085178 and learning rate: 0.009201
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 109 and iter 170257: 0.100718 and learning rate: 0.008741
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 110 and iter 171819: 0.071183 and learning rate: 0.008741
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 111 and iter 173381: 0.099778 and learning rate: 0.008741
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 112 and iter 174943: 0.070262 and learning rate: 0.008741
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 113 and iter 176505: 0.077193 and learning rate: 0.008304
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 114 and iter 178067: 0.066673 and learning rate: 0.008304
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 115 and iter 179629: 0.082719 and learning rate: 0.008304
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 116 and iter 181191: 0.064781 and learning rate: 0.007889
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 117 and iter 182753: 0.085048 and learning rate: 0.007889
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 118 and iter 184315: 0.119843 and learning rate: 0.007889
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 119 and iter 185877: 0.076099 and learning rate: 0.007495
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 120 and iter 187439: 0.065206 and learning rate: 0.007495
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 121 and iter 189001: 0.141898 and learning rate: 0.007495
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 122 and iter 190563: 0.137284 and learning rate: 0.007120
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 123 and iter 192125: 0.078145 and learning rate: 0.007120
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 124 and iter 193687: 0.056069 and learning rate: 0.007120
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 125 and iter 195249: 0.101927 and learning rate: 0.006764
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 126 and iter 196811: 0.105706 and learning rate: 0.006764
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 127 and iter 198373: 0.066902 and learning rate: 0.006764
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 128 and iter 199935: 0.078659 and learning rate: 0.006764
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 129 and iter 201497: 0.076604 and learning rate: 0.006426
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 130 and iter 203059: 0.061053 and learning rate: 0.006426
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 131 and iter 204621: 0.081814 and learning rate: 0.006426
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 132 and iter 206183: 0.061050 and learning rate: 0.006104
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 133 and iter 207745: 0.073062 and learning rate: 0.006104
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 134 and iter 209307: 0.075695 and learning rate: 0.006104
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 135 and iter 210869: 0.046386 and learning rate: 0.005799
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 136 and iter 212431: 0.084090 and learning rate: 0.005799
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 137 and iter 213993: 0.093186 and learning rate: 0.005799
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 138 and iter 215555: 0.054711 and learning rate: 0.005509
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 139 and iter 217117: 0.089411 and learning rate: 0.005509
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 140 and iter 218679: 0.077061 and learning rate: 0.005509
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 141 and iter 220241: 0.086808 and learning rate: 0.005234
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 142 and iter 221803: 0.105950 and learning rate: 0.005234
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 143 and iter 223365: 0.054791 and learning rate: 0.005234
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 144 and iter 224927: 0.080616 and learning rate: 0.005234
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 145 and iter 226489: 0.054288 and learning rate: 0.004972
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 146 and iter 228051: 0.110531 and learning rate: 0.004972
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 147 and iter 229613: 0.084166 and learning rate: 0.004972
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 148 and iter 231175: 0.072730 and learning rate: 0.004723
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 149 and iter 232737: 0.090646 and learning rate: 0.004723
# Minibatch  train and validation accuracy: 99.2%, 91.2%
# Minibatch loss at epoch 150 and iter 234299: 0.090424 and learning rate: 0.004723
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 151 and iter 235861: 0.106691 and learning rate: 0.004487
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 152 and iter 237423: 0.115565 and learning rate: 0.004487
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 153 and iter 238985: 0.076541 and learning rate: 0.004487
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 154 and iter 240547: 0.094348 and learning rate: 0.004263
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 155 and iter 242109: 0.062557 and learning rate: 0.004263
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 156 and iter 243671: 0.070204 and learning rate: 0.004263
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 157 and iter 245233: 0.055295 and learning rate: 0.004050
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 158 and iter 246795: 0.042830 and learning rate: 0.004050
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 159 and iter 248357: 0.081717 and learning rate: 0.004050
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 160 and iter 249919: 0.109313 and learning rate: 0.004050
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 161 and iter 251481: 0.071100 and learning rate: 0.003847
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 162 and iter 253043: 0.083693 and learning rate: 0.003847
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 163 and iter 254605: 0.059149 and learning rate: 0.003847
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 164 and iter 256167: 0.074746 and learning rate: 0.003655
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 165 and iter 257729: 0.078863 and learning rate: 0.003655
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 166 and iter 259291: 0.113168 and learning rate: 0.003655
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 167 and iter 260853: 0.083780 and learning rate: 0.003472
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 168 and iter 262415: 0.085299 and learning rate: 0.003472
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 169 and iter 263977: 0.100760 and learning rate: 0.003472
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 170 and iter 265539: 0.061375 and learning rate: 0.003299
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 171 and iter 267101: 0.100297 and learning rate: 0.003299
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 172 and iter 268663: 0.089535 and learning rate: 0.003299
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 173 and iter 270225: 0.065327 and learning rate: 0.003134
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 174 and iter 271787: 0.095408 and learning rate: 0.003134
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 175 and iter 273349: 0.068457 and learning rate: 0.003134
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 176 and iter 274911: 0.066561 and learning rate: 0.003134
# Minibatch  train and validation accuracy: 99.2%, 91.5%
# Model saved
# Minibatch loss at epoch 177 and iter 276473: 0.049390 and learning rate: 0.002977
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 178 and iter 278035: 0.056172 and learning rate: 0.002977
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 179 and iter 279597: 0.064470 and learning rate: 0.002977
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 180 and iter 281159: 0.081744 and learning rate: 0.002828
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 181 and iter 282721: 0.071899 and learning rate: 0.002828
# Minibatch  train and validation accuracy: 99.2%, 91.5%
# Model saved
# Minibatch loss at epoch 182 and iter 284283: 0.102359 and learning rate: 0.002828
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 183 and iter 285845: 0.054004 and learning rate: 0.002687
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 184 and iter 287407: 0.074226 and learning rate: 0.002687
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 185 and iter 288969: 0.066165 and learning rate: 0.002687
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 186 and iter 290531: 0.103626 and learning rate: 0.002552
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 187 and iter 292093: 0.101512 and learning rate: 0.002552
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 188 and iter 293655: 0.093784 and learning rate: 0.002552
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 189 and iter 295217: 0.088782 and learning rate: 0.002425
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 190 and iter 296779: 0.057227 and learning rate: 0.002425
# Minibatch  train and validation accuracy: 99.2%, 91.3%
# Minibatch loss at epoch 191 and iter 298341: 0.057785 and learning rate: 0.002425
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 192 and iter 299903: 0.053060 and learning rate: 0.002425
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 193 and iter 301465: 0.055276 and learning rate: 0.002303
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 194 and iter 303027: 0.091994 and learning rate: 0.002303
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 195 and iter 304589: 0.070734 and learning rate: 0.002303
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 196 and iter 306151: 0.065229 and learning rate: 0.002188
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 197 and iter 307713: 0.100066 and learning rate: 0.002188
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 198 and iter 309275: 0.082618 and learning rate: 0.002188
# Minibatch  train and validation accuracy: 99.2%, 91.5%
# Minibatch loss at epoch 199 and iter 310837: 0.047456 and learning rate: 0.002079
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Minibatch loss at epoch 200 and iter 312399: 0.114542 and learning rate: 0.002079
# Minibatch  train and validation accuracy: 99.2%, 91.4%
# Final Test accuracy: 96.5%
# Test accuracy with the best model: 96.6%
# Total run time 131.9474 minutes

# %% [markdown]
# ---
#
# ### Solution 4.c Model with one hidden layer (Xavier initialization)
#
# Let's see if it makes any difference for the network with 1 hidden layer when the weights are initialized with Xavier method.

# %%
# The graph

n_hidden = 1024 # Number of hidden nodes
batch_size = 500
L2_reg = 0.001 # ratio for L2 regularization

g = tf.Graph()
with g.as_default():
    
    # Placehodlers for training dataset minibatches
    tf_train_dataset = tf.placeholder(np.float32, shape=(batch_size, image_size * image_size))
    tf_train_labels = tf.placeholder(np.float32, shape=(batch_size, num_labels))
    
    # Constants for validation and test datasets
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    # Use learning rate decay
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(0.5, global_step, 1000, 0.95, staircase=True)
    
    # Define Weights and biases as variables for hidden layer
    W_1 = tf.get_variable("W1", shape=[image_size * image_size, n_hidden],
                                initializer=tf.contrib.layers.xavier_initializer())
    b_1 = tf.Variable(tf.zeros([n_hidden]))
    
    # Define Weights and biases as variables for logistic regression layer
    W_0 = tf.get_variable("W0", shape=[n_hidden, num_labels],
                                initializer=tf.contrib.layers.xavier_initializer())
    b_0 = tf.Variable(tf.zeros([num_labels]))
    
    logits_1 = tf.nn.relu(tf.matmul(tf_train_dataset, W_1) + b_1) # shape will be (batch_size, n_hidden)
    
    dropout_1 = tf.nn.dropout(logits_1, 0.5)
    
    logits_0 = tf.matmul(dropout_1, W_0) + b_0 # now the shape is (batch_size, num_labels)
    
    loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits_0)
            + L2_reg * (tf.nn.l2_loss(W_0) + tf.nn.l2_loss(W_1)))
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    # Predictions
    train_prediction = tf.nn.softmax(tf.matmul(logits_1, W_0) + b_0)
    valid_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, W_1) + b_1), W_0) + b_0)
    test_prediction = tf.nn.softmax(
        tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, W_1) + b_1), W_0) + b_0)

# %%
# Optimization part

n_epochs = 200 # number of epochs

# early-stopping parameters
patience = 5000 # look as this many examples regardless
patience_increase = 2
improvement_threshold = 0.995 # a relative improvement of 
                                  # this much is considered significant
best_valid_loss = np.inf
start_time = timeit.default_timer()

n_train_batches = train_dataset.shape[0] // batch_size

valid_freq = min(n_train_batches, patience // 2)

with tf.Session(graph=g) as sess:
    tf.global_variables_initializer().run()
    print('Initialized')
    done_looping = False
    epoch = 0
    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):
            
            batch_data = \
                train_dataset[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            batch_labels = \
                train_labels[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = sess.run(
                [optimizer, loss, train_prediction], feed_dict=feed_dict)
        
            iter = (epoch - 1) * n_train_batches + minibatch_index # cumulative iteration number
        
            if (iter + 1) % valid_freq == 0:
                this_valid_loss = 1. - (accuracy(valid_prediction.eval(), valid_labels) / 100.)
            
                print("Minibatch loss at epoch %i and iter %i: %f and learning rate: %f" % 
                      (epoch, iter, l, sess.run(learning_rate)))
                print("Minibatch  train and validation accuracy: %.1f%%, %.1f%%" 
                    % (accuracy(predictions, batch_labels), 
                    accuracy(valid_prediction.eval(), valid_labels)))
            
                if this_valid_loss < best_valid_loss:
                    if this_valid_loss < best_valid_loss * improvement_threshold:
                        patience = max(patience, iter * patience_increase)
                    
                    best_valid_loss = this_valid_loss
                    
                    params = (sess.run(W_0), sess.run(b_0),
                              sess.run(W_1), sess.run(b_1))
                    
                    # save the best model
                    with open('best_model_params.pkl', 'wb') as f:
                            pickle.dump(params, f)
                    print('Model saved')
        
            if patience <= iter:
                    done_looping = True
                    break
                    
    print("Final Test accuracy: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))
    
    with open('best_model_params.pkl', 'rb') as f:
        W_0_best, b_0_best, W_1_best, b_1_best = pickle.load(f)
        
    W_0_init, b_0_init = tf.assign(W_0, W_0_best), tf.assign(b_0, b_0_best)
    W_1_init, b_1_init = tf.assign(W_1, W_1_best), tf.assign(b_1, b_1_best)
    
    sess.run([W_0_init, b_0_init, W_1_init, b_1_init])
    
    print("Test accuracy with the best model: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))

    end_time = timeit.default_timer()

    print('Total run time %.4f minutes' % ((end_time - start_time) / 60.))
# Out:
# Initialized
# Minibatch loss at epoch 1 and iter 399: 0.867855 and learning rate: 0.500000
# Minibatch  train and validation accuracy: 84.6%, 86.0%
# Model saved
# Minibatch loss at epoch 2 and iter 799: 0.729239 and learning rate: 0.500000
# Minibatch  train and validation accuracy: 86.8%, 87.0%
# Model saved
# Minibatch loss at epoch 3 and iter 1199: 0.650370 and learning rate: 0.475000
# Minibatch  train and validation accuracy: 88.2%, 87.4%
# Model saved
# Minibatch loss at epoch 4 and iter 1599: 0.612626 and learning rate: 0.475000
# Minibatch  train and validation accuracy: 88.8%, 87.6%
# Model saved
# Minibatch loss at epoch 5 and iter 1999: 0.567722 and learning rate: 0.451250
# Minibatch  train and validation accuracy: 88.8%, 87.9%
# Model saved
# Minibatch loss at epoch 6 and iter 2399: 0.536323 and learning rate: 0.451250
# Minibatch  train and validation accuracy: 89.8%, 88.1%
# Model saved
# Minibatch loss at epoch 7 and iter 2799: 0.545947 and learning rate: 0.451250
# Minibatch  train and validation accuracy: 89.4%, 88.5%
# Model saved
# Minibatch loss at epoch 8 and iter 3199: 0.509795 and learning rate: 0.428687
# Minibatch  train and validation accuracy: 90.2%, 88.4%
# Minibatch loss at epoch 9 and iter 3599: 0.481719 and learning rate: 0.428687
# Minibatch  train and validation accuracy: 90.4%, 88.6%
# Model saved
# Minibatch loss at epoch 10 and iter 3999: 0.507714 and learning rate: 0.407253
# Minibatch  train and validation accuracy: 90.0%, 88.8%
# Model saved
# Minibatch loss at epoch 11 and iter 4399: 0.487603 and learning rate: 0.407253
# Minibatch  train and validation accuracy: 90.6%, 88.8%
# Minibatch loss at epoch 12 and iter 4799: 0.481533 and learning rate: 0.407253
# Minibatch  train and validation accuracy: 90.2%, 88.9%
# Model saved
# Minibatch loss at epoch 13 and iter 5199: 0.472795 and learning rate: 0.386890
# Minibatch  train and validation accuracy: 90.6%, 88.9%
# Model saved
# Minibatch loss at epoch 14 and iter 5599: 0.475293 and learning rate: 0.386890
# Minibatch  train and validation accuracy: 90.6%, 89.0%
# Model saved
# Minibatch loss at epoch 15 and iter 5999: 0.460769 and learning rate: 0.367546
# Minibatch  train and validation accuracy: 90.8%, 88.8%
# Minibatch loss at epoch 16 and iter 6399: 0.469874 and learning rate: 0.367546
# Minibatch  train and validation accuracy: 90.8%, 89.0%
# Minibatch loss at epoch 17 and iter 6799: 0.478123 and learning rate: 0.367546
# Minibatch  train and validation accuracy: 91.2%, 89.0%
# Model saved
# Minibatch loss at epoch 18 and iter 7199: 0.463003 and learning rate: 0.349169
# Minibatch  train and validation accuracy: 91.0%, 89.0%
# Model saved
# Minibatch loss at epoch 19 and iter 7599: 0.494393 and learning rate: 0.349169
# Minibatch  train and validation accuracy: 91.0%, 89.1%
# Model saved
# Minibatch loss at epoch 20 and iter 7999: 0.459615 and learning rate: 0.331710
# Minibatch  train and validation accuracy: 91.0%, 89.0%
# Minibatch loss at epoch 21 and iter 8399: 0.462209 and learning rate: 0.331710
# Minibatch  train and validation accuracy: 91.6%, 89.2%
# Model saved
# Minibatch loss at epoch 22 and iter 8799: 0.472461 and learning rate: 0.331710
# Minibatch  train and validation accuracy: 91.6%, 89.1%
# Minibatch loss at epoch 23 and iter 9199: 0.449607 and learning rate: 0.315125
# Minibatch  train and validation accuracy: 91.4%, 89.2%
# Model saved
# Minibatch loss at epoch 24 and iter 9599: 0.448541 and learning rate: 0.315125
# Minibatch  train and validation accuracy: 91.2%, 89.1%
# Minibatch loss at epoch 25 and iter 9999: 0.461104 and learning rate: 0.299368
# Minibatch  train and validation accuracy: 91.2%, 89.1%
# Minibatch loss at epoch 26 and iter 10399: 0.438451 and learning rate: 0.299368
# Minibatch  train and validation accuracy: 92.0%, 89.2%
# Minibatch loss at epoch 27 and iter 10799: 0.466307 and learning rate: 0.299368
# Minibatch  train and validation accuracy: 91.6%, 89.3%
# Model saved
# Minibatch loss at epoch 28 and iter 11199: 0.461005 and learning rate: 0.284400
# Minibatch  train and validation accuracy: 91.6%, 89.3%
# Model saved
# Minibatch loss at epoch 29 and iter 11599: 0.470080 and learning rate: 0.284400
# Minibatch  train and validation accuracy: 91.4%, 89.4%
# Model saved
# Minibatch loss at epoch 30 and iter 11999: 0.436046 and learning rate: 0.270180
# Minibatch  train and validation accuracy: 91.2%, 89.3%
# Minibatch loss at epoch 31 and iter 12399: 0.449483 and learning rate: 0.270180
# Minibatch  train and validation accuracy: 91.6%, 89.3%
# Minibatch loss at epoch 32 and iter 12799: 0.441139 and learning rate: 0.270180
# Minibatch  train and validation accuracy: 91.4%, 89.4%
# Model saved
# Minibatch loss at epoch 33 and iter 13199: 0.455389 and learning rate: 0.256671
# Minibatch  train and validation accuracy: 91.6%, 89.3%
# Minibatch loss at epoch 34 and iter 13599: 0.467675 and learning rate: 0.256671
# Minibatch  train and validation accuracy: 91.0%, 89.4%
# Minibatch loss at epoch 35 and iter 13999: 0.451195 and learning rate: 0.243837
# Minibatch  train and validation accuracy: 91.8%, 89.4%
# Minibatch loss at epoch 36 and iter 14399: 0.441744 and learning rate: 0.243837
# Minibatch  train and validation accuracy: 91.0%, 89.4%
# Minibatch loss at epoch 37 and iter 14799: 0.436471 and learning rate: 0.243837
# Minibatch  train and validation accuracy: 91.4%, 89.4%
# Minibatch loss at epoch 38 and iter 15199: 0.430236 and learning rate: 0.231646
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Model saved
# Minibatch loss at epoch 39 and iter 15599: 0.456001 and learning rate: 0.231646
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 40 and iter 15999: 0.447695 and learning rate: 0.220063
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 41 and iter 16399: 0.428108 and learning rate: 0.220063
# Minibatch  train and validation accuracy: 91.2%, 89.5%
# Minibatch loss at epoch 42 and iter 16799: 0.432242 and learning rate: 0.220063
# Minibatch  train and validation accuracy: 91.4%, 89.5%
# Minibatch loss at epoch 43 and iter 17199: 0.447099 and learning rate: 0.209060
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 44 and iter 17599: 0.431527 and learning rate: 0.209060
# Minibatch  train and validation accuracy: 91.8%, 89.4%
# Minibatch loss at epoch 45 and iter 17999: 0.441007 and learning rate: 0.198607
# Minibatch  train and validation accuracy: 92.2%, 89.5%
# Model saved
# Minibatch loss at epoch 46 and iter 18399: 0.456284 and learning rate: 0.198607
# Minibatch  train and validation accuracy: 91.4%, 89.6%
# Model saved
# Minibatch loss at epoch 47 and iter 18799: 0.442379 and learning rate: 0.198607
# Minibatch  train and validation accuracy: 91.6%, 89.4%
# Minibatch loss at epoch 48 and iter 19199: 0.456963 and learning rate: 0.188677
# Minibatch  train and validation accuracy: 91.6%, 89.6%
# Minibatch loss at epoch 49 and iter 19599: 0.443284 and learning rate: 0.188677
# Minibatch  train and validation accuracy: 91.8%, 89.7%
# Model saved
# Minibatch loss at epoch 50 and iter 19999: 0.432096 and learning rate: 0.179243
# Minibatch  train and validation accuracy: 92.0%, 89.5%
# Minibatch loss at epoch 51 and iter 20399: 0.444291 and learning rate: 0.179243
# Minibatch  train and validation accuracy: 91.6%, 89.5%
# Minibatch loss at epoch 52 and iter 20799: 0.422507 and learning rate: 0.179243
# Minibatch  train and validation accuracy: 91.8%, 89.5%
# Minibatch loss at epoch 53 and iter 21199: 0.440556 and learning rate: 0.170281
# Minibatch  train and validation accuracy: 91.6%, 89.7%
# Model saved
# Minibatch loss at epoch 54 and iter 21599: 0.430929 and learning rate: 0.170281
# Minibatch  train and validation accuracy: 91.8%, 89.6%
# Minibatch loss at epoch 55 and iter 21999: 0.417890 and learning rate: 0.161767
# Minibatch  train and validation accuracy: 91.6%, 89.7%
# Minibatch loss at epoch 56 and iter 22399: 0.419961 and learning rate: 0.161767
# Minibatch  train and validation accuracy: 92.0%, 89.7%
# Model saved
# Minibatch loss at epoch 57 and iter 22799: 0.439239 and learning rate: 0.161767
# Minibatch  train and validation accuracy: 91.4%, 89.7%
# Minibatch loss at epoch 58 and iter 23199: 0.429434 and learning rate: 0.153678
# Minibatch  train and validation accuracy: 92.0%, 89.6%
# Minibatch loss at epoch 59 and iter 23599: 0.433673 and learning rate: 0.153678
# Minibatch  train and validation accuracy: 91.8%, 89.7%
# Minibatch loss at epoch 60 and iter 23999: 0.425387 and learning rate: 0.145994
# Minibatch  train and validation accuracy: 92.2%, 89.8%
# Model saved
# Minibatch loss at epoch 61 and iter 24399: 0.437827 and learning rate: 0.145994
# Minibatch  train and validation accuracy: 92.2%, 89.7%
# Minibatch loss at epoch 62 and iter 24799: 0.425335 and learning rate: 0.145994
# Minibatch  train and validation accuracy: 92.2%, 89.7%
# Minibatch loss at epoch 63 and iter 25199: 0.416786 and learning rate: 0.138695
# Minibatch  train and validation accuracy: 92.0%, 89.8%
# Minibatch loss at epoch 64 and iter 25599: 0.434321 and learning rate: 0.138695
# Minibatch  train and validation accuracy: 91.6%, 89.8%
# Model saved
# Minibatch loss at epoch 65 and iter 25999: 0.416388 and learning rate: 0.131760
# Minibatch  train and validation accuracy: 91.8%, 89.6%
# Minibatch loss at epoch 66 and iter 26399: 0.405490 and learning rate: 0.131760
# Minibatch  train and validation accuracy: 92.2%, 89.6%
# Minibatch loss at epoch 67 and iter 26799: 0.411574 and learning rate: 0.131760
# Minibatch  train and validation accuracy: 92.2%, 89.7%
# Minibatch loss at epoch 68 and iter 27199: 0.433463 and learning rate: 0.125172
# Minibatch  train and validation accuracy: 91.8%, 89.7%
# Minibatch loss at epoch 69 and iter 27599: 0.423283 and learning rate: 0.125172
# Minibatch  train and validation accuracy: 91.6%, 89.7%
# Minibatch loss at epoch 70 and iter 27999: 0.417986 and learning rate: 0.118913
# Minibatch  train and validation accuracy: 92.0%, 89.7%
# Minibatch loss at epoch 71 and iter 28399: 0.403156 and learning rate: 0.118913
# Minibatch  train and validation accuracy: 91.8%, 89.8%
# Model saved
# Minibatch loss at epoch 72 and iter 28799: 0.429764 and learning rate: 0.118913
# Minibatch  train and validation accuracy: 92.0%, 89.7%
# Minibatch loss at epoch 73 and iter 29199: 0.436612 and learning rate: 0.112968
# Minibatch  train and validation accuracy: 92.6%, 89.8%
# Minibatch loss at epoch 74 and iter 29599: 0.420309 and learning rate: 0.112968
# Minibatch  train and validation accuracy: 91.8%, 89.7%
# Minibatch loss at epoch 75 and iter 29999: 0.410253 and learning rate: 0.107319
# Minibatch  train and validation accuracy: 92.0%, 89.8%
# Minibatch loss at epoch 76 and iter 30399: 0.429765 and learning rate: 0.107319
# Minibatch  train and validation accuracy: 92.2%, 89.7%
# Minibatch loss at epoch 77 and iter 30799: 0.433215 and learning rate: 0.107319
# Minibatch  train and validation accuracy: 92.4%, 89.8%
# Minibatch loss at epoch 78 and iter 31199: 0.421566 and learning rate: 0.101953
# Minibatch  train and validation accuracy: 92.4%, 89.8%
# Minibatch loss at epoch 79 and iter 31599: 0.416048 and learning rate: 0.101953
# Minibatch  train and validation accuracy: 92.0%, 89.8%
# Minibatch loss at epoch 80 and iter 31999: 0.433447 and learning rate: 0.096856
# Minibatch  train and validation accuracy: 92.2%, 89.8%
# Minibatch loss at epoch 81 and iter 32399: 0.431896 and learning rate: 0.096856
# Minibatch  train and validation accuracy: 92.2%, 89.8%
# Minibatch loss at epoch 82 and iter 32799: 0.417703 and learning rate: 0.096856
# Minibatch  train and validation accuracy: 92.4%, 89.7%
# Minibatch loss at epoch 83 and iter 33199: 0.425613 and learning rate: 0.092013
# Minibatch  train and validation accuracy: 92.2%, 89.8%
# Minibatch loss at epoch 84 and iter 33599: 0.425188 and learning rate: 0.092013
# Minibatch  train and validation accuracy: 92.6%, 89.8%
# Model saved
# Minibatch loss at epoch 85 and iter 33999: 0.407446 and learning rate: 0.087412
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Model saved
# Minibatch loss at epoch 86 and iter 34399: 0.422999 and learning rate: 0.087412
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 87 and iter 34799: 0.424183 and learning rate: 0.087412
# Minibatch  train and validation accuracy: 92.6%, 89.7%
# Minibatch loss at epoch 88 and iter 35199: 0.409898 and learning rate: 0.083042
# Minibatch  train and validation accuracy: 92.4%, 89.8%
# Minibatch loss at epoch 89 and iter 35599: 0.415943 and learning rate: 0.083042
# Minibatch  train and validation accuracy: 92.6%, 89.8%
# Minibatch loss at epoch 90 and iter 35999: 0.415897 and learning rate: 0.078890
# Minibatch  train and validation accuracy: 92.6%, 89.8%
# Minibatch loss at epoch 91 and iter 36399: 0.411220 and learning rate: 0.078890
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Model saved
# Minibatch loss at epoch 92 and iter 36799: 0.413114 and learning rate: 0.078890
# Minibatch  train and validation accuracy: 92.2%, 89.8%
# Minibatch loss at epoch 93 and iter 37199: 0.427767 and learning rate: 0.074945
# Minibatch  train and validation accuracy: 92.2%, 89.8%
# Minibatch loss at epoch 94 and iter 37599: 0.429079 and learning rate: 0.074945
# Minibatch  train and validation accuracy: 92.0%, 89.8%
# Minibatch loss at epoch 95 and iter 37999: 0.447113 and learning rate: 0.071198
# Minibatch  train and validation accuracy: 91.8%, 89.9%
# Minibatch loss at epoch 96 and iter 38399: 0.416623 and learning rate: 0.071198
# Minibatch  train and validation accuracy: 92.2%, 89.9%
# Minibatch loss at epoch 97 and iter 38799: 0.408819 and learning rate: 0.071198
# Minibatch  train and validation accuracy: 92.4%, 89.9%
# Minibatch loss at epoch 98 and iter 39199: 0.423942 and learning rate: 0.067638
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 99 and iter 39599: 0.424382 and learning rate: 0.067638
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 100 and iter 39999: 0.408472 and learning rate: 0.064256
# Minibatch  train and validation accuracy: 92.2%, 89.9%
# Minibatch loss at epoch 101 and iter 40399: 0.407672 and learning rate: 0.064256
# Minibatch  train and validation accuracy: 92.6%, 89.8%
# Minibatch loss at epoch 102 and iter 40799: 0.406630 and learning rate: 0.064256
# Minibatch  train and validation accuracy: 92.0%, 89.8%
# Minibatch loss at epoch 103 and iter 41199: 0.408338 and learning rate: 0.061043
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 104 and iter 41599: 0.424347 and learning rate: 0.061043
# Minibatch  train and validation accuracy: 92.4%, 89.8%
# Minibatch loss at epoch 105 and iter 41999: 0.395791 and learning rate: 0.057991
# Minibatch  train and validation accuracy: 92.6%, 89.8%
# Minibatch loss at epoch 106 and iter 42399: 0.412147 and learning rate: 0.057991
# Minibatch  train and validation accuracy: 92.8%, 89.8%
# Minibatch loss at epoch 107 and iter 42799: 0.422162 and learning rate: 0.057991
# Minibatch  train and validation accuracy: 92.6%, 89.8%
# Minibatch loss at epoch 108 and iter 43199: 0.399267 and learning rate: 0.055092
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 109 and iter 43599: 0.418940 and learning rate: 0.055092
# Minibatch  train and validation accuracy: 92.2%, 89.8%
# Minibatch loss at epoch 110 and iter 43999: 0.423154 and learning rate: 0.052337
# Minibatch  train and validation accuracy: 92.4%, 89.9%
# Minibatch loss at epoch 111 and iter 44399: 0.412307 and learning rate: 0.052337
# Minibatch  train and validation accuracy: 92.4%, 89.9%
# Minibatch loss at epoch 112 and iter 44799: 0.431062 and learning rate: 0.052337
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 113 and iter 45199: 0.416802 and learning rate: 0.049720
# Minibatch  train and validation accuracy: 92.4%, 89.8%
# Minibatch loss at epoch 114 and iter 45599: 0.386636 and learning rate: 0.049720
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 115 and iter 45999: 0.415686 and learning rate: 0.047234
# Minibatch  train and validation accuracy: 92.4%, 89.9%
# Minibatch loss at epoch 116 and iter 46399: 0.414165 and learning rate: 0.047234
# Minibatch  train and validation accuracy: 92.4%, 89.9%
# Minibatch loss at epoch 117 and iter 46799: 0.415916 and learning rate: 0.047234
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Model saved
# Minibatch loss at epoch 118 and iter 47199: 0.416243 and learning rate: 0.044872
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 119 and iter 47599: 0.426068 and learning rate: 0.044872
# Minibatch  train and validation accuracy: 93.0%, 89.9%
# Minibatch loss at epoch 120 and iter 47999: 0.423429 and learning rate: 0.042629
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 121 and iter 48399: 0.401812 and learning rate: 0.042629
# Minibatch  train and validation accuracy: 92.4%, 90.0%
# Minibatch loss at epoch 122 and iter 48799: 0.407014 and learning rate: 0.042629
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 123 and iter 49199: 0.415623 and learning rate: 0.040497
# Minibatch  train and validation accuracy: 92.2%, 89.9%
# Minibatch loss at epoch 124 and iter 49599: 0.437810 and learning rate: 0.040497
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 125 and iter 49999: 0.410962 and learning rate: 0.038472
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 126 and iter 50399: 0.407475 and learning rate: 0.038472
# Minibatch  train and validation accuracy: 92.8%, 89.9%
# Minibatch loss at epoch 127 and iter 50799: 0.414010 and learning rate: 0.038472
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 128 and iter 51199: 0.407700 and learning rate: 0.036549
# Minibatch  train and validation accuracy: 92.4%, 90.0%
# Minibatch loss at epoch 129 and iter 51599: 0.418909 and learning rate: 0.036549
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 130 and iter 51999: 0.422643 and learning rate: 0.034721
# Minibatch  train and validation accuracy: 92.6%, 89.9%
# Minibatch loss at epoch 131 and iter 52399: 0.392377 and learning rate: 0.034721
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Model saved
# Minibatch loss at epoch 132 and iter 52799: 0.409446 and learning rate: 0.034721
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 133 and iter 53199: 0.398455 and learning rate: 0.032985
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 134 and iter 53599: 0.412967 and learning rate: 0.032985
# Minibatch  train and validation accuracy: 92.8%, 89.9%
# Minibatch loss at epoch 135 and iter 53999: 0.417939 and learning rate: 0.031336
# Minibatch  train and validation accuracy: 92.4%, 90.0%
# Minibatch loss at epoch 136 and iter 54399: 0.422786 and learning rate: 0.031336
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 137 and iter 54799: 0.413733 and learning rate: 0.031336
# Minibatch  train and validation accuracy: 92.4%, 90.0%
# Model saved
# Minibatch loss at epoch 138 and iter 55199: 0.407119 and learning rate: 0.029769
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 139 and iter 55599: 0.414676 and learning rate: 0.029769
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 140 and iter 55999: 0.410293 and learning rate: 0.028281
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 141 and iter 56399: 0.408552 and learning rate: 0.028281
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 142 and iter 56799: 0.419584 and learning rate: 0.028281
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 143 and iter 57199: 0.412602 and learning rate: 0.026867
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 144 and iter 57599: 0.405177 and learning rate: 0.026867
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 145 and iter 57999: 0.403150 and learning rate: 0.025523
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 146 and iter 58399: 0.401518 and learning rate: 0.025523
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 147 and iter 58799: 0.407160 and learning rate: 0.025523
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 148 and iter 59199: 0.419442 and learning rate: 0.024247
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 149 and iter 59599: 0.418313 and learning rate: 0.024247
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 150 and iter 59999: 0.417039 and learning rate: 0.023035
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 151 and iter 60399: 0.420415 and learning rate: 0.023035
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 152 and iter 60799: 0.404575 and learning rate: 0.023035
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 153 and iter 61199: 0.401764 and learning rate: 0.021883
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 154 and iter 61599: 0.406095 and learning rate: 0.021883
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 155 and iter 61999: 0.415612 and learning rate: 0.020789
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 156 and iter 62399: 0.407377 and learning rate: 0.020789
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 157 and iter 62799: 0.401297 and learning rate: 0.020789
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 158 and iter 63199: 0.409050 and learning rate: 0.019750
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 159 and iter 63599: 0.389716 and learning rate: 0.019750
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 160 and iter 63999: 0.415553 and learning rate: 0.018762
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 161 and iter 64399: 0.422908 and learning rate: 0.018762
# Minibatch  train and validation accuracy: 92.6%, 90.1%
# Model saved
# Minibatch loss at epoch 162 and iter 64799: 0.419441 and learning rate: 0.018762
# Minibatch  train and validation accuracy: 93.0%, 90.0%
# Minibatch loss at epoch 163 and iter 65199: 0.410217 and learning rate: 0.017824
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 164 and iter 65599: 0.430626 and learning rate: 0.017824
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 165 and iter 65999: 0.406772 and learning rate: 0.016933
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 166 and iter 66399: 0.406675 and learning rate: 0.016933
# Minibatch  train and validation accuracy: 93.0%, 90.0%
# Minibatch loss at epoch 167 and iter 66799: 0.407866 and learning rate: 0.016933
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 168 and iter 67199: 0.406667 and learning rate: 0.016086
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 169 and iter 67599: 0.393707 and learning rate: 0.016086
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 170 and iter 67999: 0.403299 and learning rate: 0.015282
# Minibatch  train and validation accuracy: 93.0%, 89.9%
# Minibatch loss at epoch 171 and iter 68399: 0.408868 and learning rate: 0.015282
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 172 and iter 68799: 0.413582 and learning rate: 0.015282
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 173 and iter 69199: 0.417291 and learning rate: 0.014518
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 174 and iter 69599: 0.400854 and learning rate: 0.014518
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 175 and iter 69999: 0.403122 and learning rate: 0.013792
# Minibatch  train and validation accuracy: 93.0%, 90.0%
# Minibatch loss at epoch 176 and iter 70399: 0.419120 and learning rate: 0.013792
# Minibatch  train and validation accuracy: 93.0%, 90.0%
# Minibatch loss at epoch 177 and iter 70799: 0.389819 and learning rate: 0.013792
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 178 and iter 71199: 0.417430 and learning rate: 0.013102
# Minibatch  train and validation accuracy: 92.8%, 90.1%
# Minibatch loss at epoch 179 and iter 71599: 0.415183 and learning rate: 0.013102
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 180 and iter 71999: 0.405200 and learning rate: 0.012447
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 181 and iter 72399: 0.406954 and learning rate: 0.012447
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 182 and iter 72799: 0.420032 and learning rate: 0.012447
# Minibatch  train and validation accuracy: 93.0%, 90.0%
# Minibatch loss at epoch 183 and iter 73199: 0.409864 and learning rate: 0.011825
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 184 and iter 73599: 0.401868 and learning rate: 0.011825
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 185 and iter 73999: 0.419152 and learning rate: 0.011234
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 186 and iter 74399: 0.408246 and learning rate: 0.011234
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 187 and iter 74799: 0.401127 and learning rate: 0.011234
# Minibatch  train and validation accuracy: 92.8%, 90.1%
# Minibatch loss at epoch 188 and iter 75199: 0.421446 and learning rate: 0.010672
# Minibatch  train and validation accuracy: 92.8%, 90.1%
# Model saved
# Minibatch loss at epoch 189 and iter 75599: 0.416355 and learning rate: 0.010672
# Minibatch  train and validation accuracy: 92.6%, 90.1%
# Minibatch loss at epoch 190 and iter 75999: 0.403538 and learning rate: 0.010138
# Minibatch  train and validation accuracy: 93.0%, 90.1%
# Minibatch loss at epoch 191 and iter 76399: 0.409856 and learning rate: 0.010138
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 192 and iter 76799: 0.411482 and learning rate: 0.010138
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 193 and iter 77199: 0.400124 and learning rate: 0.009631
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 194 and iter 77599: 0.415339 and learning rate: 0.009631
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 195 and iter 77999: 0.395189 and learning rate: 0.009150
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 196 and iter 78399: 0.409026 and learning rate: 0.009150
# Minibatch  train and validation accuracy: 92.6%, 90.0%
# Minibatch loss at epoch 197 and iter 78799: 0.396149 and learning rate: 0.009150
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 198 and iter 79199: 0.391608 and learning rate: 0.008692
# Minibatch  train and validation accuracy: 93.0%, 90.0%
# Minibatch loss at epoch 199 and iter 79599: 0.415239 and learning rate: 0.008692
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Minibatch loss at epoch 200 and iter 79999: 0.396694 and learning rate: 0.008258
# Minibatch  train and validation accuracy: 92.8%, 90.0%
# Final Test accuracy: 95.7%
# Test accuracy with the best model: 95.7%
# Total run time 148.0104 minutes

# %% [markdown]
# It seems applying Xavier initialization to the weights improved the test accuracy.
#
# ---

# %% [markdown]
# ### Solution 4.d Model with three hidden layers
#
# And now finally let's try a network with 3 hidden layers. This time we will be also checking sanitized validation and sanitized test set accuracies that we have from assignment 1.

# %%
# The graph

n_hidden_3 = 1024  # Number of hidden nodes for hidden layer 3
n_hidden_2 = 300   # Number of hidden nodes for hidden layer 2
n_hidden_1 = 50    # Number of hidden nodes for hidden layer 1
batch_size = 128
L2_reg = 0.000 # ratio for L2 regularization

g = tf.Graph()
with g.as_default():
    
    # Placehodlers for training dataset minibatches
    tf_train_dataset = tf.placeholder(np.float32, shape=(batch_size, image_size * image_size), name='ph1')
    tf_train_labels = tf.placeholder(np.float32, shape=(batch_size, num_labels), name='ph2')
    
    # Constants for validation and test datasets
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    tf_sanit_valid_dataset = tf.constant(sanit_valid_dataset)
    tf_sanit_test_dataset = tf.constant(sanit_test_dataset)
    
    # Use learning rate decay
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(0.05, global_step, 5000, 0.95, staircase=True)
    
    # Define Weights and biases as variables for hidden layers
    W_3 = tf.get_variable("W3", shape=[image_size * image_size, n_hidden_3],
                                initializer=tf.contrib.layers.xavier_initializer())
    b_3 = tf.Variable(tf.zeros([n_hidden_3]))
    
    W_2 = tf.get_variable("W2", shape=[n_hidden_3, n_hidden_2],
                                initializer=tf.contrib.layers.xavier_initializer())
    b_2 = tf.Variable(tf.zeros([n_hidden_2]))
    
    W_1 = tf.get_variable("W1", shape=[n_hidden_2, n_hidden_1],
                                initializer=tf.contrib.layers.xavier_initializer())
    b_1 = tf.Variable(tf.zeros([n_hidden_1]))
    
    # Define Weights and biases as variables for logistic regression layer
    W_0 = tf.get_variable("W0", shape=[n_hidden_1, num_labels],
                                initializer=tf.contrib.layers.xavier_initializer())
    b_0 = tf.Variable(tf.zeros([num_labels]))
    
    logits_3 = tf.nn.relu(tf.matmul(tf_train_dataset, W_3) + b_3) # shape will be (batch_size, n_hidden_3)
    
    dropout_3 = tf.nn.dropout(logits_3, 0.5)
    
    logits_2 = tf.nn.relu(tf.matmul(dropout_3, W_2) + b_2) # shape will be (batch_size, n_hidden_2)
    
    dropout_2 = tf.nn.dropout(logits_2, 0.5)
    
    logits_1 = tf.nn.relu(tf.matmul(dropout_2, W_1) + b_1) # shape will be (batch_size, n_hidden_1)
    
    dropout_1 = tf.nn.dropout(logits_1, 0.5)
    
    logits_0 = tf.matmul(dropout_1, W_0) + b_0 # now the shape is (batch_size, num_labels)
    
    loss = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits_0)
            + L2_reg * (tf.nn.l2_loss(W_0) + tf.nn.l2_loss(W_1) 
                        + tf.nn.l2_loss(W_2) + tf.nn.l2_loss(W_3)))
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    # Predictions
    def get_logits(dataset):
        get_logits_3 = tf.nn.relu(tf.matmul(dataset, W_3) + b_3)
        get_logits_2 = tf.nn.relu(tf.matmul(get_logits_3, W_2) + b_2)
        get_logits_1 = tf.nn.relu(tf.matmul(get_logits_2, W_1) + b_1)
        get_logits_0 = tf.matmul(get_logits_1, W_0) + b_0
        return get_logits_0

    train_prediction = tf.nn.softmax(get_logits(tf_train_dataset))
    valid_prediction = tf.nn.softmax(get_logits(tf_valid_dataset))
    test_prediction = tf.nn.softmax(get_logits(tf_test_dataset))
    
    sanit_valid_prediction = tf.nn.softmax(get_logits(tf_sanit_valid_dataset))
    sanit_test_prediction = tf.nn.softmax(get_logits(tf_sanit_test_dataset))

# %%
n_epochs = 200 # number of epochs

# early-stopping parameters
patience = 5000 # look as this many examples regardless
patience_increase = 2
improvement_threshold = 0.995 # a relative improvement of 
                                  # this much is considered significant
best_valid_loss = np.inf
start_time = timeit.default_timer()

n_train_batches = train_dataset.shape[0] // batch_size

valid_freq = min(n_train_batches, patience // 2)

with tf.Session(graph=g) as sess:
    tf.global_variables_initializer().run()
    print('Initialized')
    done_looping = False
    epoch = 0
    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):
            
            batch_data = \
                train_dataset[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            batch_labels = \
                train_labels[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = sess.run(
                [optimizer, loss, train_prediction], feed_dict=feed_dict)
            
            iter = (epoch - 1) * n_train_batches + minibatch_index # cumulative iteration number
        
            if (iter + 1) % valid_freq == 0:
                this_valid_loss = 1. - (accuracy(valid_prediction.eval(), valid_labels) / 100.)
            
                print("Minibatch loss at epoch %i and iter %i: %f and learning rate: %f" % 
                      (epoch, iter, l, sess.run(learning_rate)))
                print("Minibatch  train, validation and sanitized validation accuracy: %.1f%%, %.1f%%, %.1f%%" 
                    % (accuracy(predictions, batch_labels), 
                    accuracy(valid_prediction.eval(), valid_labels),
                    accuracy(sanit_valid_prediction.eval(), sanit_valid_labels)))
            
                if this_valid_loss < best_valid_loss:
                    if this_valid_loss < best_valid_loss * improvement_threshold:
                        patience = max(patience, iter * patience_increase)
                    
                    best_valid_loss = this_valid_loss
                    
                    params = (sess.run(W_0), sess.run(b_0),
                              sess.run(W_1), sess.run(b_1),
                              sess.run(W_2), sess.run(b_2),
                              sess.run(W_3), sess.run(b_3))
                    
                    # save the best model
                    with open('best_model_params.pkl', 'wb') as f:
                            pickle.dump(params, f)
                    print('Model saved')
        
            if patience <= iter:
                    done_looping = True
                    break
                    
    print("Final Test accuracy: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))
    
    with open('best_model_params.pkl', 'rb') as f:
        W_0_best, b_0_best, W_1_best, b_1_best, W_2_best, b_2_best, W_3_best, b_3_best = pickle.load(f)
        
    W_0_init, b_0_init = tf.assign(W_0, W_0_best), tf.assign(b_0, b_0_best)
    W_1_init, b_1_init = tf.assign(W_1, W_1_best), tf.assign(b_1, b_1_best)
    W_2_init, b_2_init = tf.assign(W_2, W_2_best), tf.assign(b_2, b_2_best)
    W_3_init, b_3_init = tf.assign(W_3, W_3_best), tf.assign(b_3, b_3_best)
    
    sess.run([W_0_init, b_0_init, W_1_init, b_1_init, W_2_init, b_2_init, W_3_init, b_3_init])
    
    print("Test accuracy with the best model: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))
    
    print("Sanitized test accuracy with the best model: %.1f%%" 
                  % accuracy(sanit_test_prediction.eval(), sanit_test_labels))

    end_time = timeit.default_timer()

    print('Total run time %.4f minutes' % ((end_time - start_time) / 60.))
# Out:
# Initialized
# Minibatch loss at epoch 1 and iter 1561: 0.630508 and learning rate: 0.050000
# Minibatch  train, validation and sanitized validation accuracy: 89.8%, 84.3%, 83.3%
# Model saved
# Minibatch loss at epoch 2 and iter 3123: 0.466348 and learning rate: 0.050000
# Minibatch  train, validation and sanitized validation accuracy: 90.6%, 85.4%, 84.5%
# Model saved
# Minibatch loss at epoch 3 and iter 4685: 0.451205 and learning rate: 0.050000
# Minibatch  train, validation and sanitized validation accuracy: 89.8%, 86.3%, 85.4%
# Model saved
# Minibatch loss at epoch 4 and iter 6247: 0.441148 and learning rate: 0.047500
# Minibatch  train, validation and sanitized validation accuracy: 89.8%, 86.6%, 85.8%
# Model saved
# Minibatch loss at epoch 5 and iter 7809: 0.377883 and learning rate: 0.047500
# Minibatch  train, validation and sanitized validation accuracy: 91.4%, 87.1%, 86.3%
# Model saved
# Minibatch loss at epoch 6 and iter 9371: 0.371348 and learning rate: 0.047500
# Minibatch  train, validation and sanitized validation accuracy: 91.4%, 87.6%, 86.8%
# Model saved
# Minibatch loss at epoch 7 and iter 10933: 0.405626 and learning rate: 0.045125
# Minibatch  train, validation and sanitized validation accuracy: 90.6%, 87.9%, 87.1%
# Model saved
# Minibatch loss at epoch 8 and iter 12495: 0.272667 and learning rate: 0.045125
# Minibatch  train, validation and sanitized validation accuracy: 91.4%, 88.2%, 87.4%
# Model saved
# Minibatch loss at epoch 9 and iter 14057: 0.283011 and learning rate: 0.045125
# Minibatch  train, validation and sanitized validation accuracy: 91.4%, 88.3%, 87.5%
# Model saved
# Minibatch loss at epoch 10 and iter 15619: 0.336310 and learning rate: 0.042869
# Minibatch  train, validation and sanitized validation accuracy: 90.6%, 88.7%, 87.9%
# Model saved
# Minibatch loss at epoch 11 and iter 17181: 0.299139 and learning rate: 0.042869
# Minibatch  train, validation and sanitized validation accuracy: 92.2%, 88.7%, 87.9%
# Model saved
# Minibatch loss at epoch 12 and iter 18743: 0.305732 and learning rate: 0.042869
# Minibatch  train, validation and sanitized validation accuracy: 91.4%, 88.7%, 87.9%
# Minibatch loss at epoch 13 and iter 20305: 0.288414 and learning rate: 0.040725
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 89.0%, 88.2%
# Model saved
# Minibatch loss at epoch 14 and iter 21867: 0.244837 and learning rate: 0.040725
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 89.2%, 88.4%
# Model saved
# Minibatch loss at epoch 15 and iter 23429: 0.321253 and learning rate: 0.040725
# Minibatch  train, validation and sanitized validation accuracy: 93.0%, 89.2%, 88.4%
# Model saved
# Minibatch loss at epoch 16 and iter 24991: 0.261963 and learning rate: 0.040725
# Minibatch  train, validation and sanitized validation accuracy: 94.5%, 89.3%, 88.5%
# Model saved
# Minibatch loss at epoch 17 and iter 26553: 0.305084 and learning rate: 0.038689
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 89.2%, 88.5%
# Minibatch loss at epoch 18 and iter 28115: 0.244533 and learning rate: 0.038689
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.3%, 88.6%
# Model saved
# Minibatch loss at epoch 19 and iter 29677: 0.282443 and learning rate: 0.038689
# Minibatch  train, validation and sanitized validation accuracy: 94.5%, 89.5%, 88.7%
# Model saved
# Minibatch loss at epoch 20 and iter 31239: 0.238079 and learning rate: 0.036755
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.4%, 88.6%
# Minibatch loss at epoch 21 and iter 32801: 0.248211 and learning rate: 0.036755
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.5%, 88.8%
# Model saved
# Minibatch loss at epoch 22 and iter 34363: 0.259399 and learning rate: 0.036755
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.4%, 88.6%
# Minibatch loss at epoch 23 and iter 35925: 0.233517 and learning rate: 0.034917
# Minibatch  train, validation and sanitized validation accuracy: 94.5%, 89.5%, 88.7%
# Minibatch loss at epoch 24 and iter 37487: 0.214298 and learning rate: 0.034917
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.6%, 88.8%
# Model saved
# Minibatch loss at epoch 25 and iter 39049: 0.238082 and learning rate: 0.034917
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.7%, 89.0%
# Model saved
# Minibatch loss at epoch 26 and iter 40611: 0.192730 and learning rate: 0.033171
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.9%, 89.1%
# Model saved
# Minibatch loss at epoch 27 and iter 42173: 0.224220 and learning rate: 0.033171
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 89.8%, 89.0%
# Minibatch loss at epoch 28 and iter 43735: 0.199278 and learning rate: 0.033171
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.9%, 89.1%
# Minibatch loss at epoch 29 and iter 45297: 0.265846 and learning rate: 0.031512
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.8%, 89.1%
# Minibatch loss at epoch 30 and iter 46859: 0.212111 and learning rate: 0.031512
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 89.9%, 89.2%
# Model saved
# Minibatch loss at epoch 31 and iter 48421: 0.198108 and learning rate: 0.031512
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.0%, 89.2%
# Model saved
# Minibatch loss at epoch 32 and iter 49983: 0.204677 and learning rate: 0.031512
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 89.9%, 89.2%
# Minibatch loss at epoch 33 and iter 51545: 0.218489 and learning rate: 0.029937
# Minibatch  train, validation and sanitized validation accuracy: 95.3%, 89.9%, 89.2%
# Minibatch loss at epoch 34 and iter 53107: 0.224125 and learning rate: 0.029937
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.0%, 89.3%
# Model saved
# Minibatch loss at epoch 35 and iter 54669: 0.187586 and learning rate: 0.029937
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.2%, 89.6%
# Model saved
# Minibatch loss at epoch 36 and iter 56231: 0.243838 and learning rate: 0.028440
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.2%, 89.4%
# Minibatch loss at epoch 37 and iter 57793: 0.223521 and learning rate: 0.028440
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.1%, 89.4%
# Minibatch loss at epoch 38 and iter 59355: 0.154666 and learning rate: 0.028440
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.1%, 89.4%
# Minibatch loss at epoch 39 and iter 60917: 0.233315 and learning rate: 0.027018
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.2%, 89.5%
# Minibatch loss at epoch 40 and iter 62479: 0.158643 and learning rate: 0.027018
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.3%, 89.6%
# Model saved
# Minibatch loss at epoch 41 and iter 64041: 0.170528 and learning rate: 0.027018
# Minibatch  train, validation and sanitized validation accuracy: 96.9%, 90.2%, 89.5%
# Minibatch loss at epoch 42 and iter 65603: 0.158292 and learning rate: 0.025667
# Minibatch  train, validation and sanitized validation accuracy: 96.9%, 90.3%, 89.6%
# Minibatch loss at epoch 43 and iter 67165: 0.182184 and learning rate: 0.025667
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.1%, 89.4%
# Minibatch loss at epoch 44 and iter 68727: 0.145508 and learning rate: 0.025667
# Minibatch  train, validation and sanitized validation accuracy: 96.9%, 90.3%, 89.6%
# Minibatch loss at epoch 45 and iter 70289: 0.205529 and learning rate: 0.024384
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.4%, 89.6%
# Model saved
# Minibatch loss at epoch 46 and iter 71851: 0.153113 and learning rate: 0.024384
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.3%, 89.6%
# Minibatch loss at epoch 47 and iter 73413: 0.140833 and learning rate: 0.024384
# Minibatch  train, validation and sanitized validation accuracy: 96.9%, 90.3%, 89.6%
# Minibatch loss at epoch 48 and iter 74975: 0.159742 and learning rate: 0.024384
# Minibatch  train, validation and sanitized validation accuracy: 96.1%, 90.4%, 89.7%
# Model saved
# Minibatch loss at epoch 49 and iter 76537: 0.185925 and learning rate: 0.023165
# Minibatch  train, validation and sanitized validation accuracy: 96.9%, 90.4%, 89.7%
# Minibatch loss at epoch 50 and iter 78099: 0.144480 and learning rate: 0.023165
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.5%, 89.8%
# Model saved
# Minibatch loss at epoch 51 and iter 79661: 0.138634 and learning rate: 0.023165
# Minibatch  train, validation and sanitized validation accuracy: 96.9%, 90.5%, 89.8%
# Model saved
# Minibatch loss at epoch 52 and iter 81223: 0.223114 and learning rate: 0.022006
# Minibatch  train, validation and sanitized validation accuracy: 96.9%, 90.3%, 89.5%
# Minibatch loss at epoch 53 and iter 82785: 0.120496 and learning rate: 0.022006
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.5%, 89.8%
# Minibatch loss at epoch 54 and iter 84347: 0.157761 and learning rate: 0.022006
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.5%, 89.7%
# Minibatch loss at epoch 55 and iter 85909: 0.147748 and learning rate: 0.020906
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.6%, 89.9%
# Model saved
# Minibatch loss at epoch 56 and iter 87471: 0.227653 and learning rate: 0.020906
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.4%, 89.7%
# Minibatch loss at epoch 57 and iter 89033: 0.176592 and learning rate: 0.020906
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.3%, 89.6%
# Minibatch loss at epoch 58 and iter 90595: 0.173348 and learning rate: 0.019861
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.5%, 89.8%
# Minibatch loss at epoch 59 and iter 92157: 0.141320 and learning rate: 0.019861
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.5%, 89.8%
# Minibatch loss at epoch 60 and iter 93719: 0.162435 and learning rate: 0.019861
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.5%, 89.8%
# Minibatch loss at epoch 61 and iter 95281: 0.195673 and learning rate: 0.018868
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.7%, 89.9%
# Model saved
# Minibatch loss at epoch 62 and iter 96843: 0.211141 and learning rate: 0.018868
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.4%, 89.6%
# Minibatch loss at epoch 63 and iter 98405: 0.115368 and learning rate: 0.018868
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.7%, 90.0%
# Model saved
# Minibatch loss at epoch 64 and iter 99967: 0.145032 and learning rate: 0.018868
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.6%, 89.9%
# Minibatch loss at epoch 65 and iter 101529: 0.160051 and learning rate: 0.017924
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.6%, 89.8%
# Minibatch loss at epoch 66 and iter 103091: 0.184494 and learning rate: 0.017924
# Minibatch  train, validation and sanitized validation accuracy: 96.9%, 90.6%, 89.8%
# Minibatch loss at epoch 67 and iter 104653: 0.182886 and learning rate: 0.017924
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.6%, 89.9%
# Minibatch loss at epoch 68 and iter 106215: 0.144511 and learning rate: 0.017028
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.6%, 89.8%
# Minibatch loss at epoch 69 and iter 107777: 0.155203 and learning rate: 0.017028
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.6%, 89.9%
# Minibatch loss at epoch 70 and iter 109339: 0.133019 and learning rate: 0.017028
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.7%, 90.0%
# Minibatch loss at epoch 71 and iter 110901: 0.188832 and learning rate: 0.016177
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.7%, 90.0%
# Minibatch loss at epoch 72 and iter 112463: 0.164549 and learning rate: 0.016177
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.7%, 90.0%
# Model saved
# Minibatch loss at epoch 73 and iter 114025: 0.162341 and learning rate: 0.016177
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.1%
# Model saved
# Minibatch loss at epoch 74 and iter 115587: 0.178650 and learning rate: 0.015368
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.1%
# Model saved
# Minibatch loss at epoch 75 and iter 117149: 0.162992 and learning rate: 0.015368
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.7%, 90.0%
# Minibatch loss at epoch 76 and iter 118711: 0.176812 and learning rate: 0.015368
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.1%
# Minibatch loss at epoch 77 and iter 120273: 0.122518 and learning rate: 0.014599
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.0%
# Minibatch loss at epoch 78 and iter 121835: 0.135359 and learning rate: 0.014599
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.7%, 90.0%
# Minibatch loss at epoch 79 and iter 123397: 0.161945 and learning rate: 0.014599
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.1%
# Minibatch loss at epoch 80 and iter 124959: 0.154932 and learning rate: 0.014599
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.9%, 90.2%
# Model saved
# Minibatch loss at epoch 81 and iter 126521: 0.125325 and learning rate: 0.013869
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.0%
# Minibatch loss at epoch 82 and iter 128083: 0.125472 and learning rate: 0.013869
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Minibatch loss at epoch 83 and iter 129645: 0.105008 and learning rate: 0.013869
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Model saved
# Minibatch loss at epoch 84 and iter 131207: 0.182087 and learning rate: 0.013176
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.1%
# Minibatch loss at epoch 85 and iter 132769: 0.139104 and learning rate: 0.013176
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.0%
# Minibatch loss at epoch 86 and iter 134331: 0.108216 and learning rate: 0.013176
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Minibatch loss at epoch 87 and iter 135893: 0.151312 and learning rate: 0.012517
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Model saved
# Minibatch loss at epoch 88 and iter 137455: 0.178466 and learning rate: 0.012517
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.1%
# Minibatch loss at epoch 89 and iter 139017: 0.090427 and learning rate: 0.012517
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Minibatch loss at epoch 90 and iter 140579: 0.128738 and learning rate: 0.011891
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Minibatch loss at epoch 91 and iter 142141: 0.171129 and learning rate: 0.011891
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.8%, 90.1%
# Minibatch loss at epoch 92 and iter 143703: 0.223992 and learning rate: 0.011891
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Minibatch loss at epoch 93 and iter 145265: 0.122465 and learning rate: 0.011297
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 91.0%, 90.3%
# Minibatch loss at epoch 94 and iter 146827: 0.104235 and learning rate: 0.011297
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.9%, 90.2%
# Minibatch loss at epoch 95 and iter 148389: 0.166775 and learning rate: 0.011297
# Minibatch  train, validation and sanitized validation accuracy: 97.7%, 90.9%, 90.2%
# Minibatch loss at epoch 96 and iter 149951: 0.162133 and learning rate: 0.011297
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Minibatch loss at epoch 97 and iter 151513: 0.159461 and learning rate: 0.010732
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Minibatch loss at epoch 98 and iter 153075: 0.125935 and learning rate: 0.010732
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Model saved
# Minibatch loss at epoch 99 and iter 154637: 0.119884 and learning rate: 0.010732
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Minibatch loss at epoch 100 and iter 156199: 0.156949 and learning rate: 0.010195
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Minibatch loss at epoch 101 and iter 157761: 0.116754 and learning rate: 0.010195
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.2%
# Minibatch loss at epoch 102 and iter 159323: 0.119325 and learning rate: 0.010195
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Minibatch loss at epoch 103 and iter 160885: 0.147021 and learning rate: 0.009686
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Model saved
# Minibatch loss at epoch 104 and iter 162447: 0.203030 and learning rate: 0.009686
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 105 and iter 164009: 0.133659 and learning rate: 0.009686
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 106 and iter 165571: 0.129607 and learning rate: 0.009201
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Minibatch loss at epoch 107 and iter 167133: 0.132331 and learning rate: 0.009201
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Minibatch loss at epoch 108 and iter 168695: 0.115872 and learning rate: 0.009201
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Minibatch loss at epoch 109 and iter 170257: 0.130952 and learning rate: 0.008741
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 90.9%, 90.2%
# Minibatch loss at epoch 110 and iter 171819: 0.131714 and learning rate: 0.008741
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Minibatch loss at epoch 111 and iter 173381: 0.117324 and learning rate: 0.008741
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 112 and iter 174943: 0.150713 and learning rate: 0.008741
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Model saved
# Minibatch loss at epoch 113 and iter 176505: 0.124636 and learning rate: 0.008304
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Minibatch loss at epoch 114 and iter 178067: 0.170209 and learning rate: 0.008304
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 115 and iter 179629: 0.172317 and learning rate: 0.008304
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 116 and iter 181191: 0.134854 and learning rate: 0.007889
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 117 and iter 182753: 0.090523 and learning rate: 0.007889
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 118 and iter 184315: 0.122644 and learning rate: 0.007889
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Model saved
# Minibatch loss at epoch 119 and iter 185877: 0.118726 and learning rate: 0.007495
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 120 and iter 187439: 0.129906 and learning rate: 0.007495
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 121 and iter 189001: 0.135516 and learning rate: 0.007495
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.5%
# Minibatch loss at epoch 122 and iter 190563: 0.099613 and learning rate: 0.007120
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Model saved
# Minibatch loss at epoch 123 and iter 192125: 0.163080 and learning rate: 0.007120
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Minibatch loss at epoch 124 and iter 193687: 0.129212 and learning rate: 0.007120
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 125 and iter 195249: 0.105928 and learning rate: 0.006764
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 126 and iter 196811: 0.135531 and learning rate: 0.006764
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 127 and iter 198373: 0.079440 and learning rate: 0.006764
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 128 and iter 199935: 0.110378 and learning rate: 0.006764
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 129 and iter 201497: 0.085254 and learning rate: 0.006426
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 130 and iter 203059: 0.113592 and learning rate: 0.006426
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 131 and iter 204621: 0.138259 and learning rate: 0.006426
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Model saved
# Minibatch loss at epoch 132 and iter 206183: 0.074752 and learning rate: 0.006104
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 133 and iter 207745: 0.102388 and learning rate: 0.006104
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 134 and iter 209307: 0.147650 and learning rate: 0.006104
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 135 and iter 210869: 0.162124 and learning rate: 0.005799
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.4%
# Minibatch loss at epoch 136 and iter 212431: 0.156839 and learning rate: 0.005799
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 137 and iter 213993: 0.203554 and learning rate: 0.005799
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.0%, 90.3%
# Minibatch loss at epoch 138 and iter 215555: 0.153070 and learning rate: 0.005509
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.3%
# Minibatch loss at epoch 139 and iter 217117: 0.101286 and learning rate: 0.005509
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 140 and iter 218679: 0.089177 and learning rate: 0.005509
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 141 and iter 220241: 0.159385 and learning rate: 0.005234
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 142 and iter 221803: 0.131903 and learning rate: 0.005234
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 143 and iter 223365: 0.125548 and learning rate: 0.005234
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 144 and iter 224927: 0.087441 and learning rate: 0.005234
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.4%
# Minibatch loss at epoch 145 and iter 226489: 0.131514 and learning rate: 0.004972
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 146 and iter 228051: 0.093089 and learning rate: 0.004972
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 147 and iter 229613: 0.110010 and learning rate: 0.004972
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 148 and iter 231175: 0.100133 and learning rate: 0.004723
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 149 and iter 232737: 0.091111 and learning rate: 0.004723
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 150 and iter 234299: 0.065397 and learning rate: 0.004723
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.1%, 90.5%
# Minibatch loss at epoch 151 and iter 235861: 0.115737 and learning rate: 0.004487
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 152 and iter 237423: 0.135689 and learning rate: 0.004487
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 153 and iter 238985: 0.130917 and learning rate: 0.004487
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 154 and iter 240547: 0.091628 and learning rate: 0.004263
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Model saved
# Minibatch loss at epoch 155 and iter 242109: 0.087996 and learning rate: 0.004263
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Model saved
# Minibatch loss at epoch 156 and iter 243671: 0.065278 and learning rate: 0.004263
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Model saved
# Minibatch loss at epoch 157 and iter 245233: 0.112909 and learning rate: 0.004050
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 158 and iter 246795: 0.083177 and learning rate: 0.004050
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 159 and iter 248357: 0.110407 and learning rate: 0.004050
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 160 and iter 249919: 0.130591 and learning rate: 0.004050
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 161 and iter 251481: 0.103890 and learning rate: 0.003847
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 162 and iter 253043: 0.132440 and learning rate: 0.003847
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 163 and iter 254605: 0.089545 and learning rate: 0.003847
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 164 and iter 256167: 0.113140 and learning rate: 0.003655
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 165 and iter 257729: 0.111335 and learning rate: 0.003655
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Model saved
# Minibatch loss at epoch 166 and iter 259291: 0.082611 and learning rate: 0.003655
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 167 and iter 260853: 0.116567 and learning rate: 0.003472
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 168 and iter 262415: 0.116492 and learning rate: 0.003472
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 169 and iter 263977: 0.079694 and learning rate: 0.003472
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 170 and iter 265539: 0.125537 and learning rate: 0.003299
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 171 and iter 267101: 0.122359 and learning rate: 0.003299
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 172 and iter 268663: 0.068909 and learning rate: 0.003299
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 173 and iter 270225: 0.080212 and learning rate: 0.003134
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 174 and iter 271787: 0.100854 and learning rate: 0.003134
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 175 and iter 273349: 0.156662 and learning rate: 0.003134
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 176 and iter 274911: 0.068103 and learning rate: 0.003134
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 177 and iter 276473: 0.157724 and learning rate: 0.002977
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.4%, 90.7%
# Model saved
# Minibatch loss at epoch 178 and iter 278035: 0.093432 and learning rate: 0.002977
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.7%
# Minibatch loss at epoch 179 and iter 279597: 0.103653 and learning rate: 0.002977
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.4%, 90.7%
# Minibatch loss at epoch 180 and iter 281159: 0.140332 and learning rate: 0.002828
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.7%
# Minibatch loss at epoch 181 and iter 282721: 0.108863 and learning rate: 0.002828
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 182 and iter 284283: 0.081379 and learning rate: 0.002828
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 183 and iter 285845: 0.116390 and learning rate: 0.002687
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 184 and iter 287407: 0.084121 and learning rate: 0.002687
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 185 and iter 288969: 0.088881 and learning rate: 0.002687
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 186 and iter 290531: 0.077259 and learning rate: 0.002552
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 187 and iter 292093: 0.107267 and learning rate: 0.002552
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 188 and iter 293655: 0.113566 and learning rate: 0.002552
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.7%
# Minibatch loss at epoch 189 and iter 295217: 0.115315 and learning rate: 0.002425
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.5%
# Minibatch loss at epoch 190 and iter 296779: 0.127259 and learning rate: 0.002425
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 191 and iter 298341: 0.106627 and learning rate: 0.002425
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.2%, 90.6%
# Minibatch loss at epoch 192 and iter 299903: 0.091700 and learning rate: 0.002425
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.7%
# Minibatch loss at epoch 193 and iter 301465: 0.118895 and learning rate: 0.002303
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 194 and iter 303027: 0.090303 and learning rate: 0.002303
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 195 and iter 304589: 0.181126 and learning rate: 0.002303
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 196 and iter 306151: 0.128146 and learning rate: 0.002188
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.7%
# Minibatch loss at epoch 197 and iter 307713: 0.158499 and learning rate: 0.002188
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Minibatch loss at epoch 198 and iter 309275: 0.082163 and learning rate: 0.002188
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.7%
# Minibatch loss at epoch 199 and iter 310837: 0.080006 and learning rate: 0.002079
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.4%, 90.7%
# Minibatch loss at epoch 200 and iter 312399: 0.136036 and learning rate: 0.002079
# Minibatch  train, validation and sanitized validation accuracy: 98.4%, 91.3%, 90.6%
# Final Test accuracy: 96.5%
# Test accuracy with the best model: 96.5%
# Sanitized test accuracy with the best model: 96.1%
# Total run time 122.5897 minutes

# %% [markdown]
# ---
