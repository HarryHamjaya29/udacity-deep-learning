# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

#my imports
import timeit
from functools import reduce

# %%
pickle_file = 'notMNIST.pickle'
sanitized_pickle_file = 'notMNIST_sanitized.pickle' # additional work (it includes cleaned test and valid datasets)

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)

with open(sanitized_pickle_file, 'rb') as f:
  save = pickle.load(f)
  sanit_valid_dataset = save['valid_dataset']
  sanit_valid_labels = save['valid_labels']
  sanit_test_dataset = save['test_dataset']
  sanit_test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('\nsanit_Validation set', sanit_valid_dataset.shape, sanit_valid_labels.shape)
  print('sanit_Test set', sanit_test_dataset.shape, sanit_test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)
#
# sanit_Validation set (8984, 28, 28) (8984,)
# sanit_Test set (8709, 28, 28) (8709,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)

sanit_valid_dataset, sanit_valid_labels = reformat(sanit_valid_dataset, sanit_valid_labels)
sanit_test_dataset, sanit_test_labels = reformat(sanit_test_dataset, sanit_test_labels)

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)

print('\nsanitValidation set', sanit_valid_dataset.shape, sanit_valid_labels.shape)
print('sanitTest set', sanit_test_dataset.shape, sanit_test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)
#
# sanitValidation set (8984, 28, 28, 1) (8984, 10)
# sanitTest set (8709, 28, 28, 1) (8709, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases

  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.115222
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.2%
# Minibatch loss at step 50: 1.371427
# Minibatch accuracy: 50.0%
# Validation accuracy: 54.9%
# Minibatch loss at step 100: 1.262059
# Minibatch accuracy: 62.5%
# Validation accuracy: 68.5%
# Minibatch loss at step 150: 0.893900
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.6%
# Minibatch loss at step 200: 0.415209
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 250: 0.581476
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 300: 0.718953
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 350: 0.729384
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 400: 0.856863
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.1%
# Minibatch loss at step 450: 1.358471
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 500: 0.561696
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 1.337894
# Minibatch accuracy: 56.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 600: 0.540955
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 650: 0.410924
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 700: 0.591362
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 750: 0.214771
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 800: 0.306935
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 850: 0.572451
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 900: 0.355042
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 950: 0.251927
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 1000: 0.502512
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Test accuracy: 88.3%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %% [markdown]
# ## Solution 1

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

g = tf.Graph()

with g.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  tf_sanit_valid_dataset = tf.constant(sanit_valid_dataset)
  tf_sanit_test_dataset = tf.constant(sanit_test_dataset)
  
  # Variables.
  W_1 = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  b_1 = tf.Variable(tf.zeros([depth]))
  W_2 = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  b_2 = tf.Variable(tf.constant(1.0, shape=[depth]))
  W_3 = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  b_3 = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  W_4 = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  b_4 = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, W_1, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + b_1)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, W_2, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + b_2)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, W_3) + b_3)
    return tf.matmul(hidden, W_4) + b_4

  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))
  sanit_valid_prediction = tf.nn.softmax(model(tf_sanit_valid_dataset))
  sanit_test_prediction = tf.nn.softmax(model(tf_sanit_test_dataset))

# %%
# Optimization

n_epochs = 200 # number of epochs

# early-stopping parameters
patience = 5000 # look as this many examples regardless
patience_increase = 2
improvement_threshold = 0.995 # a relative improvement of 
                                  # this much is considered significant
best_valid_loss = np.inf
start_time = timeit.default_timer()

n_train_batches = train_dataset.shape[0] // batch_size

valid_freq = min(n_train_batches, patience // 2)

with tf.Session(graph=g) as sess:
    tf.global_variables_initializer().run()
    print('Initialized')
    done_looping = False
    epoch = 0
    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):
            
            batch_data = \
                train_dataset[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            batch_labels = \
                train_labels[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = sess.run(
                [optimizer, loss, train_prediction], feed_dict=feed_dict)
        
            iter = (epoch - 1) * n_train_batches + minibatch_index # cumulative iteration number
        
            if (iter + 1) % valid_freq == 0:
                this_valid_loss = 1. - (accuracy(valid_prediction.eval(), valid_labels) / 100.)
            
                print("Minibatch loss at epoch %i and iter %i: %f" % 
                      (epoch, iter, l))
                print("Minibatch  train, validation and sanitized validation accuracy: %.1f%%, %.1f%%, %.1f%%" 
                    % (accuracy(predictions, batch_labels), 
                    accuracy(valid_prediction.eval(), valid_labels),
                    accuracy(sanit_valid_prediction.eval(), sanit_valid_labels)))
            
                if this_valid_loss < best_valid_loss:
                    if this_valid_loss < best_valid_loss * improvement_threshold:
                        patience = max(patience, iter * patience_increase)
                    
                    best_valid_loss = this_valid_loss
                    
                    params = (sess.run(W_1), sess.run(b_1),
                              sess.run(W_2), sess.run(b_2),
                              sess.run(W_3), sess.run(b_3),
                              sess.run(W_4), sess.run(b_4))
                    
                    # save the best model
                    with open('best_model_params.pkl', 'wb') as f:
                            pickle.dump(params, f)
                    print('Model saved')
        
            if patience <= iter:
                    done_looping = True
                    break
                    
    print("Final Test accuracy: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))
    
    with open('best_model_params.pkl', 'rb') as f:
        (W_1_best, b_1_best, W_2_best, b_2_best,
         W_3_best, b_3_best, W_4_best, b_4_best) = pickle.load(f)
    
    W_1_init, b_1_init = tf.assign(W_1, W_1_best), tf.assign(b_1, b_1_best)
    W_2_init, b_2_init = tf.assign(W_2, W_2_best), tf.assign(b_2, b_2_best)
    W_3_init, b_3_init = tf.assign(W_3, W_3_best), tf.assign(b_3, b_3_best)
    W_4_init, b_4_init = tf.assign(W_4, W_4_best), tf.assign(b_4, b_4_best)
    
    sess.run([W_1_init, b_1_init,
              W_2_init, b_2_init,
              W_3_init, b_3_init,
              W_4_init, b_4_init])
    
    print("Test accuracy with the best model: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))
    
    print("Sanitized test accuracy with the best model: %.1f%%" 
                  % accuracy(sanit_test_prediction.eval(), sanit_test_labels))

    end_time = timeit.default_timer()

    print('Total run time %.4f minutes' % ((end_time - start_time) / 60.))
# Out:
# Initialized
# Minibatch loss at epoch 1 and iter 2499: 0.377919
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 85.9%, 85.0%
# Model saved
# Minibatch loss at epoch 1 and iter 4999: 0.218864
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 86.8%, 86.0%
# Model saved
# Minibatch loss at epoch 1 and iter 7499: 0.391378
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 88.0%, 87.3%
# Model saved
# Minibatch loss at epoch 1 and iter 9999: 0.366130
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 89.0%, 88.3%
# Model saved
# Minibatch loss at epoch 1 and iter 12499: 0.656173
# Minibatch  train, validation and sanitized validation accuracy: 81.2%, 89.0%, 88.3%
# Minibatch loss at epoch 2 and iter 14999: 0.211207
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 89.5%, 88.8%
# Model saved
# Minibatch loss at epoch 2 and iter 17499: 0.206505
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 89.5%, 88.8%
# Model saved
# Minibatch loss at epoch 2 and iter 19999: 0.359015
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 89.5%, 88.7%
# Minibatch loss at epoch 2 and iter 22499: 0.375379
# Minibatch  train, validation and sanitized validation accuracy: 81.2%, 90.0%, 89.3%
# Model saved
# Minibatch loss at epoch 2 and iter 24999: 0.724298
# Minibatch  train, validation and sanitized validation accuracy: 75.0%, 89.6%, 88.8%
# Minibatch loss at epoch 3 and iter 27499: 0.229080
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.1%, 89.5%
# Model saved
# Minibatch loss at epoch 3 and iter 29999: 0.232174
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.2%, 89.5%
# Model saved
# Minibatch loss at epoch 3 and iter 32499: 0.325141
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.2%, 89.6%
# Model saved
# Minibatch loss at epoch 3 and iter 34999: 0.370447
# Minibatch  train, validation and sanitized validation accuracy: 81.2%, 90.3%, 89.6%
# Model saved
# Minibatch loss at epoch 3 and iter 37499: 0.757915
# Minibatch  train, validation and sanitized validation accuracy: 75.0%, 90.0%, 89.3%
# Minibatch loss at epoch 4 and iter 39999: 0.246182
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.5%, 89.9%
# Model saved
# Minibatch loss at epoch 4 and iter 42499: 0.259362
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.2%, 89.5%
# Minibatch loss at epoch 4 and iter 44999: 0.303973
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.3%, 89.7%
# Minibatch loss at epoch 4 and iter 47499: 0.351462
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.4%, 89.7%
# Minibatch loss at epoch 4 and iter 49999: 0.825429
# Minibatch  train, validation and sanitized validation accuracy: 68.8%, 90.5%, 89.8%
# Model saved
# Minibatch loss at epoch 5 and iter 52499: 0.195369
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.8%, 90.3%
# Model saved
# Minibatch loss at epoch 5 and iter 54999: 0.184809
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.3%, 89.7%
# Minibatch loss at epoch 5 and iter 57499: 0.277581
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.5%, 89.8%
# Minibatch loss at epoch 5 and iter 59999: 0.357163
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.3%, 89.7%
# Minibatch loss at epoch 5 and iter 62499: 0.743744
# Minibatch  train, validation and sanitized validation accuracy: 68.8%, 90.6%, 90.0%
# Minibatch loss at epoch 6 and iter 64999: 0.205858
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.8%, 90.2%
# Minibatch loss at epoch 6 and iter 67499: 0.194259
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.5%, 89.8%
# Minibatch loss at epoch 6 and iter 69999: 0.291663
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.5%, 89.9%
# Minibatch loss at epoch 6 and iter 72499: 0.389839
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.6%, 90.0%
# Minibatch loss at epoch 6 and iter 74999: 0.771742
# Minibatch  train, validation and sanitized validation accuracy: 68.8%, 90.7%, 90.0%
# Minibatch loss at epoch 7 and iter 77499: 0.163518
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.9%, 90.3%
# Model saved
# Minibatch loss at epoch 7 and iter 79999: 0.176000
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.7%, 90.0%
# Minibatch loss at epoch 7 and iter 82499: 0.289036
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.6%, 89.9%
# Minibatch loss at epoch 7 and iter 84999: 0.363358
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.7%, 90.0%
# Minibatch loss at epoch 7 and iter 87499: 0.689812
# Minibatch  train, validation and sanitized validation accuracy: 68.8%, 90.5%, 89.7%
# Minibatch loss at epoch 8 and iter 89999: 0.181807
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.8%, 90.2%
# Minibatch loss at epoch 8 and iter 92499: 0.218714
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.5%, 89.8%
# Minibatch loss at epoch 8 and iter 94999: 0.284824
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.6%, 90.0%
# Minibatch loss at epoch 8 and iter 97499: 0.358913
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.7%, 90.0%
# Minibatch loss at epoch 8 and iter 99999: 0.631747
# Minibatch  train, validation and sanitized validation accuracy: 81.2%, 90.5%, 89.9%
# Minibatch loss at epoch 9 and iter 102499: 0.181932
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.5%, 89.8%
# Minibatch loss at epoch 9 and iter 104999: 0.211311
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.9%, 90.2%
# Minibatch loss at epoch 9 and iter 107499: 0.278102
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.6%, 90.0%
# Minibatch loss at epoch 9 and iter 109999: 0.353288
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.9%, 90.3%
# Minibatch loss at epoch 9 and iter 112499: 0.748754
# Minibatch  train, validation and sanitized validation accuracy: 75.0%, 90.7%, 90.0%
# Minibatch loss at epoch 10 and iter 114999: 0.171321
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.8%, 90.2%
# Minibatch loss at epoch 10 and iter 117499: 0.236561
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.5%, 89.8%
# Minibatch loss at epoch 10 and iter 119999: 0.302238
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.5%, 89.8%
# Minibatch loss at epoch 10 and iter 122499: 0.315728
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.7%, 90.1%
# Minibatch loss at epoch 10 and iter 124999: 0.644799
# Minibatch  train, validation and sanitized validation accuracy: 75.0%, 90.2%, 89.5%
# Minibatch loss at epoch 11 and iter 127499: 0.102844
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 91.0%, 90.3%
# Model saved
# Minibatch loss at epoch 11 and iter 129999: 0.226391
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.7%, 90.0%
# Minibatch loss at epoch 11 and iter 132499: 0.278371
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.2%, 89.5%
# Minibatch loss at epoch 11 and iter 134999: 0.318733
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.9%, 90.3%
# Minibatch loss at epoch 11 and iter 137499: 0.777922
# Minibatch  train, validation and sanitized validation accuracy: 68.8%, 90.3%, 89.7%
# Minibatch loss at epoch 12 and iter 139999: 0.164702
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.9%, 90.3%
# Minibatch loss at epoch 12 and iter 142499: 0.160666
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.7%, 90.1%
# Minibatch loss at epoch 12 and iter 144999: 0.268137
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.4%, 89.7%
# Minibatch loss at epoch 12 and iter 147499: 0.342425
# Minibatch  train, validation and sanitized validation accuracy: 87.5%, 90.8%, 90.1%
# Minibatch loss at epoch 12 and iter 149999: 0.570828
# Minibatch  train, validation and sanitized validation accuracy: 75.0%, 90.3%, 89.7%
# Minibatch loss at epoch 13 and iter 152499: 0.154342
# Minibatch  train, validation and sanitized validation accuracy: 93.8%, 90.7%, 90.1%
# Final Test accuracy: 96.0%
# Test accuracy with the best model: 96.4%
# Sanitized test accuracy with the best model: 95.9%
# Total run time 44.7739 minutes

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# ## Solution 2
#
# Let's try LeNet-5 model with dropouts and learning rate decay.

# %%
# Graph with GPU support

batch_size = 32
patch_size = 5

g = tf.Graph()

config = tf.ConfigProto(allow_soft_placement = True)

with tf.device('/gpu:0'):
#with g.as_default():
    # Input data.
    tf_train_dataset = tf.placeholder(
      tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    tf_sanit_valid_dataset = tf.constant(sanit_valid_dataset)
    tf_sanit_test_dataset = tf.constant(sanit_test_dataset)
    
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(0.1, global_step, 10000, 0.95, staircase=True)
    
    # Variables.
    W_1 = tf.get_variable("W1", shape=[patch_size, patch_size, num_channels, 6],
                                 initializer=tf.contrib.layers.xavier_initializer())
    b_1 = tf.Variable(tf.zeros([6]))
    
    W_2 = tf.get_variable("W2", shape=[patch_size, patch_size, 6, 16],
                                 initializer=tf.contrib.layers.xavier_initializer())
    b_2 = tf.Variable(tf.zeros([16]))
    
    W_3 = tf.get_variable("W3", shape=[5 * 5 * 16, 120],
                                 initializer=tf.contrib.layers.xavier_initializer())
    b_3 = tf.Variable(tf.zeros([120]))
    
    W_4 = tf.get_variable("W4", shape=[120, 84],
                                 initializer=tf.contrib.layers.xavier_initializer())
    b_4 = tf.Variable(tf.zeros([84]))
    
    W_5 = tf.get_variable("W5", shape=[84, num_labels],
                                 initializer=tf.contrib.layers.xavier_initializer())
    b_5 = tf.Variable(tf.zeros([num_labels]))
    
    # Model.
    def model(data, dropout=False):
        conv = tf.nn.conv2d(data, W_1, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + b_1)
        
        pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        conv = tf.nn.conv2d(pool, W_2, [1, 1, 1, 1], padding='VALID')
        hidden = tf.nn.relu(conv + b_2)
        
        pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        
        shape = pool.get_shape().as_list()
        reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])

        hidden = tf.nn.relu(tf.matmul(reshape, W_3) + b_3)
        if dropout:
            hidden = tf.nn.dropout(hidden, 0.5)

        hidden = tf.nn.relu(tf.matmul(hidden, W_4) + b_4)
        if dropout:
            hidden = tf.nn.dropout(hidden, 0.5)
        
        return tf.matmul(hidden, W_5) + b_5
    
    # Training computation.
    logits = model(tf_train_dataset, dropout=True)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
      
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))
    sanit_valid_prediction = tf.nn.softmax(model(tf_sanit_valid_dataset))
    sanit_test_prediction = tf.nn.softmax(model(tf_sanit_test_dataset))

# %%
# Optimization

n_epochs = 200 # number of epochs

# early-stopping parameters
patience = 5000 # look as this many examples regardless
patience_increase = 2
improvement_threshold = 0.995 # a relative improvement of 
                                  # this much is considered significant
best_valid_loss = np.inf
start_time = timeit.default_timer()
prev_time = start_time

n_train_batches = train_dataset.shape[0] // batch_size

valid_freq = min(n_train_batches, patience // 2)

epoch_freq_ratio = max(1, n_train_batches // (patience // 2))

delta_t = []
with tf.Session(config=config) as sess:
#with tf.Session(graph=g) as sess:
    tf.global_variables_initializer().run()
    print('Initialized')
    done_looping = False
    epoch = 0
    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):
            
            batch_data = \
                train_dataset[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            batch_labels = \
                train_labels[minibatch_index * batch_size:(minibatch_index + 1) * batch_size, :]
            feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
            _, l, predictions = sess.run(
                [optimizer, loss, train_prediction], feed_dict=feed_dict)
        
            iter = (epoch - 1) * n_train_batches + minibatch_index # cumulative iteration number
        
            if (iter + 1) % valid_freq == 0:
                this_valid_loss = 1. - (accuracy(valid_prediction.eval(), valid_labels) / 100.)
            
                print("Minibatch loss at epoch %i and iter %i: %f and the learning rate: %f" % 
                      (epoch, iter, l, learning_rate.eval()))
                print("Minibatch  train, validation and sanitized validation accuracy: %.3f%%, %.3f%%, %.3f%%" 
                    % (accuracy(predictions, batch_labels), 
                    accuracy(valid_prediction.eval(), valid_labels),
                    accuracy(sanit_valid_prediction.eval(), sanit_valid_labels)))

                end_time = timeit.default_timer()

                delta_t.append(end_time - prev_time)
                
                print('Time interval: %.4f seconds, estimated run time for %i epochs: %.4f hours' % 
                        ((end_time - prev_time), n_epochs, 
                        ((reduce(lambda x, y: x + y, delta_t) / len(delta_t)) 
                         * n_epochs * epoch_freq_ratio) / 3600.))
                
                prev_time = end_time
            
                if this_valid_loss < best_valid_loss:
                    if this_valid_loss < best_valid_loss * improvement_threshold:
                        patience = max(patience, iter * patience_increase)
                    
                    best_valid_loss = this_valid_loss
                    
                    params = (sess.run(W_1), sess.run(b_1),
                              sess.run(W_2), sess.run(b_2),
                              sess.run(W_3), sess.run(b_3),
                              sess.run(W_4), sess.run(b_4),
                              sess.run(W_5), sess.run(b_5))
                    
                    # save the best model
                    with open('best_model_params.pkl', 'wb') as f:
                            pickle.dump(params, f)
                    print('Model saved')
        
            if patience <= iter:
                    done_looping = True
                    break
                    
    print("Final Test accuracy: %.1f%%" 
                  % accuracy(test_prediction.eval(), test_labels))
    
    with open('best_model_params.pkl', 'rb') as f:
        (W_1_best, b_1_best, 
         W_2_best, b_2_best,
         W_3_best, b_3_best, 
         W_4_best, b_4_best,
         W_5_best, b_5_best) = pickle.load(f)
    
    W_1_init, b_1_init = tf.assign(W_1, W_1_best), tf.assign(b_1, b_1_best)
    W_2_init, b_2_init = tf.assign(W_2, W_2_best), tf.assign(b_2, b_2_best)
    W_3_init, b_3_init = tf.assign(W_3, W_3_best), tf.assign(b_3, b_3_best)
    W_4_init, b_4_init = tf.assign(W_4, W_4_best), tf.assign(b_4, b_4_best)
    W_5_init, b_5_init = tf.assign(W_5, W_5_best), tf.assign(b_5, b_5_best)
    
    sess.run([W_1_init, b_1_init,
              W_2_init, b_2_init,
              W_3_init, b_3_init,
              W_4_init, b_4_init,
              W_5_init, b_5_init])
    
    print("Test accuracy with the best model: %.3f%%" 
                  % accuracy(test_prediction.eval(), test_labels))
    
    print("Sanitized test accuracy with the best model: %.3f%%" 
                  % accuracy(sanit_test_prediction.eval(), sanit_test_labels))

    end_time = timeit.default_timer()

    print('Total run time %.4f minutes' % ((end_time - start_time) / 60.))

    sess.close()
# Out:
# Initialized
# Minibatch loss at epoch 1 and iter 2499: 0.294367 and the learning rate: 0.100000
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 86.300%, 85.452%
# Time interval: 17.2607 seconds, estimated run time for 200 epochs: 1.9179 hours
# Model saved
# Minibatch loss at epoch 1 and iter 4999: 0.541414 and the learning rate: 0.100000
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 87.480%, 86.587%
# Time interval: 14.8643 seconds, estimated run time for 200 epochs: 1.7847 hours
# Model saved
# Minibatch loss at epoch 2 and iter 7499: 0.475043 and the learning rate: 0.100000
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 88.230%, 87.444%
# Time interval: 15.9236 seconds, estimated run time for 200 epochs: 1.7796 hours
# Model saved
# Minibatch loss at epoch 2 and iter 9999: 0.327063 and the learning rate: 0.095000
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 88.530%, 87.756%
# Time interval: 17.0853 seconds, estimated run time for 200 epochs: 1.8093 hours
# Model saved
# Minibatch loss at epoch 2 and iter 12499: 0.778118 and the learning rate: 0.095000
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 88.810%, 88.034%
# Time interval: 19.4936 seconds, estimated run time for 200 epochs: 1.8806 hours
# Model saved
# Minibatch loss at epoch 3 and iter 14999: 0.233809 and the learning rate: 0.095000
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 89.030%, 88.279%
# Time interval: 16.3434 seconds, estimated run time for 200 epochs: 1.8698 hours
# Model saved
# Minibatch loss at epoch 3 and iter 17499: 0.478486 and the learning rate: 0.095000
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 88.650%, 87.867%
# Time interval: 19.5279 seconds, estimated run time for 200 epochs: 1.9127 hours
# Minibatch loss at epoch 4 and iter 19999: 0.341425 and the learning rate: 0.090250
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 89.400%, 88.724%
# Time interval: 20.0239 seconds, estimated run time for 200 epochs: 1.9517 hours
# Model saved
# Minibatch loss at epoch 4 and iter 22499: 0.208076 and the learning rate: 0.090250
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 89.470%, 88.780%
# Time interval: 20.9071 seconds, estimated run time for 200 epochs: 1.9930 hours
# Model saved
# Minibatch loss at epoch 4 and iter 24999: 0.678879 and the learning rate: 0.090250
# Minibatch  train, validation and sanitized validation accuracy: 78.125%, 89.470%, 88.758%
# Time interval: 18.5077 seconds, estimated run time for 200 epochs: 1.9993 hours
# Minibatch loss at epoch 5 and iter 27499: 0.183869 and the learning rate: 0.090250
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 89.420%, 88.691%
# Time interval: 18.4000 seconds, estimated run time for 200 epochs: 2.0034 hours
# Minibatch loss at epoch 5 and iter 29999: 0.527665 and the learning rate: 0.085737
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 89.850%, 89.136%
# Time interval: 19.2662 seconds, estimated run time for 200 epochs: 2.0148 hours
# Model saved
# Minibatch loss at epoch 6 and iter 32499: 0.441333 and the learning rate: 0.085737
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 89.750%, 89.114%
# Time interval: 24.3946 seconds, estimated run time for 200 epochs: 2.0684 hours
# Minibatch loss at epoch 6 and iter 34999: 0.319228 and the learning rate: 0.085737
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 89.870%, 89.181%
# Time interval: 27.0505 seconds, estimated run time for 200 epochs: 2.1353 hours
# Model saved
# Minibatch loss at epoch 6 and iter 37499: 0.813280 and the learning rate: 0.085737
# Minibatch  train, validation and sanitized validation accuracy: 75.000%, 89.870%, 89.192%
# Time interval: 20.6726 seconds, estimated run time for 200 epochs: 2.1461 hours
# Minibatch loss at epoch 7 and iter 39999: 0.183118 and the learning rate: 0.081451
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 89.800%, 89.103%
# Time interval: 19.0696 seconds, estimated run time for 200 epochs: 2.1444 hours
# Minibatch loss at epoch 7 and iter 42499: 0.424787 and the learning rate: 0.081451
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.170%, 89.448%
# Time interval: 18.8491 seconds, estimated run time for 200 epochs: 2.1414 hours
# Model saved
# Minibatch loss at epoch 8 and iter 44999: 0.345919 and the learning rate: 0.081451
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 90.390%, 89.726%
# Time interval: 25.6827 seconds, estimated run time for 200 epochs: 2.1810 hours
# Model saved
# Minibatch loss at epoch 8 and iter 47499: 0.316048 and the learning rate: 0.081451
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.380%, 89.715%
# Time interval: 21.2285 seconds, estimated run time for 200 epochs: 2.1904 hours
# Minibatch loss at epoch 8 and iter 49999: 0.743152 and the learning rate: 0.077378
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 89.850%, 89.181%
# Time interval: 19.6512 seconds, estimated run time for 200 epochs: 2.1900 hours
# Minibatch loss at epoch 9 and iter 52499: 0.175395 and the learning rate: 0.077378
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 90.040%, 89.348%
# Time interval: 23.9416 seconds, estimated run time for 200 epochs: 2.2124 hours
# Minibatch loss at epoch 9 and iter 54999: 0.443781 and the learning rate: 0.077378
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.110%, 89.415%
# Time interval: 19.1433 seconds, estimated run time for 200 epochs: 2.2085 hours
# Minibatch loss at epoch 10 and iter 57499: 0.327513 and the learning rate: 0.077378
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 90.240%, 89.593%
# Time interval: 18.7574 seconds, estimated run time for 200 epochs: 2.2031 hours
# Minibatch loss at epoch 10 and iter 59999: 0.312369 and the learning rate: 0.073509
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.270%, 89.659%
# Time interval: 19.0019 seconds, estimated run time for 200 epochs: 2.1993 hours
# Minibatch loss at epoch 10 and iter 62499: 0.745823 and the learning rate: 0.073509
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 90.410%, 89.748%
# Time interval: 24.7198 seconds, estimated run time for 200 epochs: 2.2212 hours
# Model saved
# Minibatch loss at epoch 11 and iter 64999: 0.216661 and the learning rate: 0.073509
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.600%, 89.982%
# Time interval: 20.5452 seconds, estimated run time for 200 epochs: 2.2236 hours
# Model saved
# Minibatch loss at epoch 11 and iter 67499: 0.416084 and the learning rate: 0.073509
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.300%, 89.626%
# Time interval: 23.5547 seconds, estimated run time for 200 epochs: 2.2381 hours
# Minibatch loss at epoch 12 and iter 69999: 0.382385 and the learning rate: 0.069834
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 90.210%, 89.570%
# Time interval: 18.6236 seconds, estimated run time for 200 epochs: 2.2321 hours
# Minibatch loss at epoch 12 and iter 72499: 0.205121 and the learning rate: 0.069834
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.610%, 89.960%
# Time interval: 18.5025 seconds, estimated run time for 200 epochs: 2.2260 hours
# Model saved
# Minibatch loss at epoch 12 and iter 74999: 0.459634 and the learning rate: 0.069834
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.510%, 89.849%
# Time interval: 21.2592 seconds, estimated run time for 200 epochs: 2.2306 hours
# Minibatch loss at epoch 13 and iter 77499: 0.224499 and the learning rate: 0.069834
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.400%, 89.771%
# Time interval: 33.8014 seconds, estimated run time for 200 epochs: 2.2798 hours
# Minibatch loss at epoch 13 and iter 79999: 0.421039 and the learning rate: 0.066342
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.430%, 89.760%
# Time interval: 21.7941 seconds, estimated run time for 200 epochs: 2.2842 hours
# Minibatch loss at epoch 14 and iter 82499: 0.300528 and the learning rate: 0.066342
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.530%, 89.904%
# Time interval: 18.4124 seconds, estimated run time for 200 epochs: 2.2770 hours
# Minibatch loss at epoch 14 and iter 84999: 0.268215 and the learning rate: 0.066342
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.580%, 89.938%
# Time interval: 18.1309 seconds, estimated run time for 200 epochs: 2.2693 hours
# Minibatch loss at epoch 14 and iter 87499: 0.468058 and the learning rate: 0.066342
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 90.370%, 89.693%
# Time interval: 18.5539 seconds, estimated run time for 200 epochs: 2.2633 hours
# Minibatch loss at epoch 15 and iter 89999: 0.281861 and the learning rate: 0.063025
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.470%, 89.793%
# Time interval: 23.6561 seconds, estimated run time for 200 epochs: 2.2735 hours
# Minibatch loss at epoch 15 and iter 92499: 0.418851 and the learning rate: 0.063025
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.520%, 89.860%
# Time interval: 24.2549 seconds, estimated run time for 200 epochs: 2.2849 hours
# Minibatch loss at epoch 16 and iter 94999: 0.333885 and the learning rate: 0.063025
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.640%, 90.004%
# Time interval: 24.0444 seconds, estimated run time for 200 epochs: 2.2950 hours
# Model saved
# Minibatch loss at epoch 16 and iter 97499: 0.242850 and the learning rate: 0.063025
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.620%, 89.927%
# Time interval: 26.1778 seconds, estimated run time for 200 epochs: 2.3108 hours
# Minibatch loss at epoch 16 and iter 99999: 0.743037 and the learning rate: 0.059874
# Minibatch  train, validation and sanitized validation accuracy: 75.000%, 90.680%, 90.027%
# Time interval: 19.2244 seconds, estimated run time for 200 epochs: 2.3064 hours
# Model saved
# Minibatch loss at epoch 17 and iter 102499: 0.147815 and the learning rate: 0.059874
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.890%, 90.238%
# Time interval: 20.6507 seconds, estimated run time for 200 epochs: 2.3061 hours
# Model saved
# Minibatch loss at epoch 17 and iter 104999: 0.435810 and the learning rate: 0.059874
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.580%, 89.927%
# Time interval: 30.4761 seconds, estimated run time for 200 epochs: 2.3318 hours
# Minibatch loss at epoch 18 and iter 107499: 0.395346 and the learning rate: 0.059874
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 90.790%, 90.194%
# Time interval: 24.7334 seconds, estimated run time for 200 epochs: 2.3415 hours
# Minibatch loss at epoch 18 and iter 109999: 0.275487 and the learning rate: 0.056880
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.550%, 89.882%
# Time interval: 30.5018 seconds, estimated run time for 200 epochs: 2.3653 hours
# Minibatch loss at epoch 18 and iter 112499: 0.731942 and the learning rate: 0.056880
# Minibatch  train, validation and sanitized validation accuracy: 78.125%, 90.510%, 89.849%
# Time interval: 23.2032 seconds, estimated run time for 200 epochs: 2.3700 hours
# Minibatch loss at epoch 19 and iter 114999: 0.219013 and the learning rate: 0.056880
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.760%, 90.127%
# Time interval: 30.8609 seconds, estimated run time for 200 epochs: 2.3931 hours
# Minibatch loss at epoch 19 and iter 117499: 0.442643 and the learning rate: 0.056880
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 90.620%, 89.960%
# Time interval: 22.1427 seconds, estimated run time for 200 epochs: 2.3945 hours
# Minibatch loss at epoch 20 and iter 119999: 0.300888 and the learning rate: 0.054036
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.760%, 90.160%
# Time interval: 19.4342 seconds, estimated run time for 200 epochs: 2.3896 hours
# Minibatch loss at epoch 20 and iter 122499: 0.247264 and the learning rate: 0.054036
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.630%, 89.971%
# Time interval: 21.0317 seconds, estimated run time for 200 epochs: 2.3885 hours
# Minibatch loss at epoch 20 and iter 124999: 0.539234 and the learning rate: 0.054036
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 90.820%, 90.205%
# Time interval: 29.8513 seconds, estimated run time for 200 epochs: 2.4071 hours
# Minibatch loss at epoch 21 and iter 127499: 0.184055 and the learning rate: 0.054036
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 90.910%, 90.305%
# Time interval: 19.1817 seconds, estimated run time for 200 epochs: 2.4017 hours
# Model saved
# Minibatch loss at epoch 21 and iter 129999: 0.403313 and the learning rate: 0.051334
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.870%, 90.216%
# Time interval: 18.5608 seconds, estimated run time for 200 epochs: 2.3952 hours
# Minibatch loss at epoch 22 and iter 132499: 0.230955 and the learning rate: 0.051334
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.860%, 90.238%
# Time interval: 30.5064 seconds, estimated run time for 200 epochs: 2.4139 hours
# Minibatch loss at epoch 22 and iter 134999: 0.257078 and the learning rate: 0.051334
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.890%, 90.272%
# Time interval: 22.5566 seconds, estimated run time for 200 epochs: 2.4156 hours
# Minibatch loss at epoch 22 and iter 137499: 0.536864 and the learning rate: 0.051334
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 90.890%, 90.249%
# Time interval: 19.0771 seconds, estimated run time for 200 epochs: 2.4102 hours
# Minibatch loss at epoch 23 and iter 139999: 0.165362 and the learning rate: 0.048767
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 90.860%, 90.216%
# Time interval: 20.4911 seconds, estimated run time for 200 epochs: 2.4079 hours
# Minibatch loss at epoch 23 and iter 142499: 0.333634 and the learning rate: 0.048767
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.880%, 90.227%
# Time interval: 21.8746 seconds, estimated run time for 200 epochs: 2.4083 hours
# Minibatch loss at epoch 24 and iter 144999: 0.253551 and the learning rate: 0.048767
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.840%, 90.194%
# Time interval: 23.2219 seconds, estimated run time for 200 epochs: 2.4112 hours
# Minibatch loss at epoch 24 and iter 147499: 0.289776 and the learning rate: 0.048767
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.950%, 90.316%
# Time interval: 21.7460 seconds, estimated run time for 200 epochs: 2.4113 hours
# Model saved
# Minibatch loss at epoch 24 and iter 149999: 0.570930 and the learning rate: 0.046329
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 90.810%, 90.171%
# Time interval: 21.9625 seconds, estimated run time for 200 epochs: 2.4118 hours
# Minibatch loss at epoch 25 and iter 152499: 0.228504 and the learning rate: 0.046329
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.970%, 90.327%
# Time interval: 18.6871 seconds, estimated run time for 200 epochs: 2.4063 hours
# Model saved
# Minibatch loss at epoch 25 and iter 154999: 0.352479 and the learning rate: 0.046329
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.700%, 90.038%
# Time interval: 24.2118 seconds, estimated run time for 200 epochs: 2.4109 hours
# Minibatch loss at epoch 26 and iter 157499: 0.274986 and the learning rate: 0.046329
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.030%, 90.427%
# Time interval: 25.2614 seconds, estimated run time for 200 epochs: 2.4172 hours
# Model saved
# Minibatch loss at epoch 26 and iter 159999: 0.265686 and the learning rate: 0.044013
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.870%, 90.216%
# Time interval: 19.1557 seconds, estimated run time for 200 epochs: 2.4126 hours
# Minibatch loss at epoch 26 and iter 162499: 0.553767 and the learning rate: 0.044013
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.020%, 90.405%
# Time interval: 25.1052 seconds, estimated run time for 200 epochs: 2.4184 hours
# Minibatch loss at epoch 27 and iter 164999: 0.191960 and the learning rate: 0.044013
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.030%, 90.461%
# Time interval: 18.7801 seconds, estimated run time for 200 epochs: 2.4134 hours
# Minibatch loss at epoch 27 and iter 167499: 0.356282 and the learning rate: 0.044013
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.960%, 90.327%
# Time interval: 20.3694 seconds, estimated run time for 200 epochs: 2.4112 hours
# Minibatch loss at epoch 28 and iter 169999: 0.271221 and the learning rate: 0.041812
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.060%, 90.450%
# Time interval: 22.2467 seconds, estimated run time for 200 epochs: 2.4121 hours
# Model saved
# Minibatch loss at epoch 28 and iter 172499: 0.221901 and the learning rate: 0.041812
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.090%, 90.472%
# Time interval: 24.7997 seconds, estimated run time for 200 epochs: 2.4170 hours
# Model saved
# Minibatch loss at epoch 28 and iter 174999: 0.522582 and the learning rate: 0.041812
# Minibatch  train, validation and sanitized validation accuracy: 78.125%, 90.810%, 90.160%
# Time interval: 20.1742 seconds, estimated run time for 200 epochs: 2.4145 hours
# Minibatch loss at epoch 29 and iter 177499: 0.119560 and the learning rate: 0.041812
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 90.890%, 90.272%
# Time interval: 20.5367 seconds, estimated run time for 200 epochs: 2.4127 hours
# Minibatch loss at epoch 29 and iter 179999: 0.398934 and the learning rate: 0.039721
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.110%, 90.494%
# Time interval: 20.9503 seconds, estimated run time for 200 epochs: 2.4115 hours
# Model saved
# Minibatch loss at epoch 30 and iter 182499: 0.270494 and the learning rate: 0.039721
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.970%, 90.338%
# Time interval: 20.2607 seconds, estimated run time for 200 epochs: 2.4093 hours
# Minibatch loss at epoch 30 and iter 184999: 0.264677 and the learning rate: 0.039721
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.190%, 90.583%
# Time interval: 23.1295 seconds, estimated run time for 200 epochs: 2.4115 hours
# Model saved
# Minibatch loss at epoch 30 and iter 187499: 0.422488 and the learning rate: 0.039721
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.720%, 90.049%
# Time interval: 22.2074 seconds, estimated run time for 200 epochs: 2.4122 hours
# Minibatch loss at epoch 31 and iter 189999: 0.102148 and the learning rate: 0.037735
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 90.790%, 90.171%
# Time interval: 20.5110 seconds, estimated run time for 200 epochs: 2.4105 hours
# Minibatch loss at epoch 31 and iter 192499: 0.322705 and the learning rate: 0.037735
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.960%, 90.316%
# Time interval: 18.5104 seconds, estimated run time for 200 epochs: 2.4059 hours
# Minibatch loss at epoch 32 and iter 194999: 0.211306 and the learning rate: 0.037735
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.130%, 90.528%
# Time interval: 18.7833 seconds, estimated run time for 200 epochs: 2.4018 hours
# Minibatch loss at epoch 32 and iter 197499: 0.183756 and the learning rate: 0.037735
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 90.900%, 90.272%
# Time interval: 19.6126 seconds, estimated run time for 200 epochs: 2.3990 hours
# Minibatch loss at epoch 32 and iter 199999: 0.387088 and the learning rate: 0.035849
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.010%, 90.394%
# Time interval: 20.6699 seconds, estimated run time for 200 epochs: 2.3977 hours
# Minibatch loss at epoch 33 and iter 202499: 0.128321 and the learning rate: 0.035849
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.050%, 90.416%
# Time interval: 20.9725 seconds, estimated run time for 200 epochs: 2.3968 hours
# Minibatch loss at epoch 33 and iter 204999: 0.391533 and the learning rate: 0.035849
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.970%, 90.316%
# Time interval: 20.8633 seconds, estimated run time for 200 epochs: 2.3959 hours
# Minibatch loss at epoch 34 and iter 207499: 0.182985 and the learning rate: 0.035849
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.090%, 90.483%
# Time interval: 20.5373 seconds, estimated run time for 200 epochs: 2.3945 hours
# Minibatch loss at epoch 34 and iter 209999: 0.214274 and the learning rate: 0.034056
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.090%, 90.461%
# Time interval: 22.7712 seconds, estimated run time for 200 epochs: 2.3961 hours
# Minibatch loss at epoch 34 and iter 212499: 0.444695 and the learning rate: 0.034056
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 90.960%, 90.316%
# Time interval: 20.6005 seconds, estimated run time for 200 epochs: 2.3949 hours
# Minibatch loss at epoch 35 and iter 214999: 0.121614 and the learning rate: 0.034056
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.840%, 90.160%
# Time interval: 18.4002 seconds, estimated run time for 200 epochs: 2.3908 hours
# Minibatch loss at epoch 35 and iter 217499: 0.414532 and the learning rate: 0.034056
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.960%, 90.316%
# Time interval: 23.3549 seconds, estimated run time for 200 epochs: 2.3931 hours
# Minibatch loss at epoch 36 and iter 219999: 0.242867 and the learning rate: 0.032353
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.970%, 90.361%
# Time interval: 23.7310 seconds, estimated run time for 200 epochs: 2.3959 hours
# Minibatch loss at epoch 36 and iter 222499: 0.201543 and the learning rate: 0.032353
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.050%, 90.416%
# Time interval: 19.4982 seconds, estimated run time for 200 epochs: 2.3933 hours
# Minibatch loss at epoch 36 and iter 224999: 0.497037 and the learning rate: 0.032353
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 91.020%, 90.361%
# Time interval: 18.2676 seconds, estimated run time for 200 epochs: 2.3893 hours
# Minibatch loss at epoch 37 and iter 227499: 0.193228 and the learning rate: 0.032353
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.040%, 90.439%
# Time interval: 18.2761 seconds, estimated run time for 200 epochs: 2.3854 hours
# Minibatch loss at epoch 37 and iter 229999: 0.351943 and the learning rate: 0.030736
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.860%, 90.205%
# Time interval: 18.4189 seconds, estimated run time for 200 epochs: 2.3817 hours
# Minibatch loss at epoch 38 and iter 232499: 0.296054 and the learning rate: 0.030736
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.000%, 90.350%
# Time interval: 23.4256 seconds, estimated run time for 200 epochs: 2.3840 hours
# Minibatch loss at epoch 38 and iter 234999: 0.335950 and the learning rate: 0.030736
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.010%, 90.361%
# Time interval: 19.4332 seconds, estimated run time for 200 epochs: 2.3817 hours
# Minibatch loss at epoch 38 and iter 237499: 0.543605 and the learning rate: 0.030736
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.060%, 90.405%
# Time interval: 20.4373 seconds, estimated run time for 200 epochs: 2.3805 hours
# Minibatch loss at epoch 39 and iter 239999: 0.289903 and the learning rate: 0.029199
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.090%, 90.472%
# Time interval: 20.2659 seconds, estimated run time for 200 epochs: 2.3791 hours
# Minibatch loss at epoch 39 and iter 242499: 0.507819 and the learning rate: 0.029199
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.050%, 90.405%
# Time interval: 23.8940 seconds, estimated run time for 200 epochs: 2.3820 hours
# Minibatch loss at epoch 40 and iter 244999: 0.200263 and the learning rate: 0.029199
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.190%, 90.561%
# Time interval: 19.1381 seconds, estimated run time for 200 epochs: 2.3794 hours
# Minibatch loss at epoch 40 and iter 247499: 0.258719 and the learning rate: 0.029199
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.060%, 90.427%
# Time interval: 18.2763 seconds, estimated run time for 200 epochs: 2.3759 hours
# Minibatch loss at epoch 40 and iter 249999: 0.449787 and the learning rate: 0.027739
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.060%, 90.427%
# Time interval: 20.5043 seconds, estimated run time for 200 epochs: 2.3749 hours
# Minibatch loss at epoch 41 and iter 252499: 0.108791 and the learning rate: 0.027739
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.050%, 90.439%
# Time interval: 18.3538 seconds, estimated run time for 200 epochs: 2.3716 hours
# Minibatch loss at epoch 41 and iter 254999: 0.501157 and the learning rate: 0.027739
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.050%, 90.372%
# Time interval: 18.2893 seconds, estimated run time for 200 epochs: 2.3682 hours
# Minibatch loss at epoch 42 and iter 257499: 0.145831 and the learning rate: 0.027739
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.210%, 90.561%
# Time interval: 22.7845 seconds, estimated run time for 200 epochs: 2.3698 hours
# Model saved
# Minibatch loss at epoch 42 and iter 259999: 0.298359 and the learning rate: 0.026352
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.180%, 90.550%
# Time interval: 21.9785 seconds, estimated run time for 200 epochs: 2.3705 hours
# Minibatch loss at epoch 42 and iter 262499: 0.415876 and the learning rate: 0.026352
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.150%, 90.516%
# Time interval: 18.5884 seconds, estimated run time for 200 epochs: 2.3676 hours
# Minibatch loss at epoch 43 and iter 264999: 0.119398 and the learning rate: 0.026352
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.170%, 90.516%
# Time interval: 18.3465 seconds, estimated run time for 200 epochs: 2.3645 hours
# Minibatch loss at epoch 43 and iter 267499: 0.394950 and the learning rate: 0.026352
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 90.810%, 90.127%
# Time interval: 20.4535 seconds, estimated run time for 200 epochs: 2.3636 hours
# Minibatch loss at epoch 44 and iter 269999: 0.238623 and the learning rate: 0.025034
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.110%, 90.472%
# Time interval: 21.8228 seconds, estimated run time for 200 epochs: 2.3642 hours
# Minibatch loss at epoch 44 and iter 272499: 0.234130 and the learning rate: 0.025034
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.090%, 90.439%
# Time interval: 18.3151 seconds, estimated run time for 200 epochs: 2.3612 hours
# Minibatch loss at epoch 44 and iter 274999: 0.441670 and the learning rate: 0.025034
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.080%, 90.427%
# Time interval: 18.4250 seconds, estimated run time for 200 epochs: 2.3583 hours
# Minibatch loss at epoch 45 and iter 277499: 0.123877 and the learning rate: 0.025034
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.000%, 90.338%
# Time interval: 18.4294 seconds, estimated run time for 200 epochs: 2.3555 hours
# Minibatch loss at epoch 45 and iter 279999: 0.430622 and the learning rate: 0.023783
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.030%, 90.405%
# Time interval: 26.2999 seconds, estimated run time for 200 epochs: 2.3606 hours
# Minibatch loss at epoch 46 and iter 282499: 0.238716 and the learning rate: 0.023783
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.080%, 90.427%
# Time interval: 21.1848 seconds, estimated run time for 200 epochs: 2.3605 hours
# Minibatch loss at epoch 46 and iter 284999: 0.297995 and the learning rate: 0.023783
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.180%, 90.528%
# Time interval: 18.2501 seconds, estimated run time for 200 epochs: 2.3576 hours
# Minibatch loss at epoch 46 and iter 287499: 0.454755 and the learning rate: 0.023783
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.110%, 90.483%
# Time interval: 17.9834 seconds, estimated run time for 200 epochs: 2.3545 hours
# Minibatch loss at epoch 47 and iter 289999: 0.106593 and the learning rate: 0.022594
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.300%, 90.683%
# Time interval: 18.3790 seconds, estimated run time for 200 epochs: 2.3518 hours
# Model saved
# Minibatch loss at epoch 47 and iter 292499: 0.420164 and the learning rate: 0.022594
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.040%, 90.372%
# Time interval: 20.1036 seconds, estimated run time for 200 epochs: 2.3508 hours
# Minibatch loss at epoch 48 and iter 294999: 0.112880 and the learning rate: 0.022594
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.220%, 90.583%
# Time interval: 20.0239 seconds, estimated run time for 200 epochs: 2.3497 hours
# Minibatch loss at epoch 48 and iter 297499: 0.256367 and the learning rate: 0.022594
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.110%, 90.461%
# Time interval: 18.4504 seconds, estimated run time for 200 epochs: 2.3472 hours
# Minibatch loss at epoch 48 and iter 299999: 0.545683 and the learning rate: 0.021464
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.240%, 90.617%
# Time interval: 22.1293 seconds, estimated run time for 200 epochs: 2.3481 hours
# Minibatch loss at epoch 49 and iter 302499: 0.140699 and the learning rate: 0.021464
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.350%, 90.750%
# Time interval: 19.9784 seconds, estimated run time for 200 epochs: 2.3471 hours
# Model saved
# Minibatch loss at epoch 49 and iter 304999: 0.474806 and the learning rate: 0.021464
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.150%, 90.516%
# Time interval: 19.8193 seconds, estimated run time for 200 epochs: 2.3459 hours
# Minibatch loss at epoch 50 and iter 307499: 0.214521 and the learning rate: 0.021464
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 90.920%, 90.283%
# Time interval: 20.5225 seconds, estimated run time for 200 epochs: 2.3454 hours
# Minibatch loss at epoch 50 and iter 309999: 0.275429 and the learning rate: 0.020391
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.130%, 90.472%
# Time interval: 21.9157 seconds, estimated run time for 200 epochs: 2.3461 hours
# Minibatch loss at epoch 50 and iter 312499: 0.404918 and the learning rate: 0.020391
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 91.070%, 90.427%
# Time interval: 20.3501 seconds, estimated run time for 200 epochs: 2.3454 hours
# Minibatch loss at epoch 51 and iter 314999: 0.117453 and the learning rate: 0.020391
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.210%, 90.572%
# Time interval: 18.2375 seconds, estimated run time for 200 epochs: 2.3429 hours
# Minibatch loss at epoch 51 and iter 317499: 0.455209 and the learning rate: 0.020391
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.160%, 90.494%
# Time interval: 18.6282 seconds, estimated run time for 200 epochs: 2.3407 hours
# Minibatch loss at epoch 52 and iter 319999: 0.242232 and the learning rate: 0.019371
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.040%, 90.394%
# Time interval: 18.8026 seconds, estimated run time for 200 epochs: 2.3388 hours
# Minibatch loss at epoch 52 and iter 322499: 0.204918 and the learning rate: 0.019371
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.170%, 90.550%
# Time interval: 18.2861 seconds, estimated run time for 200 epochs: 2.3364 hours
# Minibatch loss at epoch 52 and iter 324999: 0.421708 and the learning rate: 0.019371
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.150%, 90.516%
# Time interval: 19.4557 seconds, estimated run time for 200 epochs: 2.3350 hours
# Minibatch loss at epoch 53 and iter 327499: 0.187558 and the learning rate: 0.019371
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.140%, 90.528%
# Time interval: 22.0927 seconds, estimated run time for 200 epochs: 2.3359 hours
# Minibatch loss at epoch 53 and iter 329999: 0.403599 and the learning rate: 0.018403
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.090%, 90.405%
# Time interval: 19.2313 seconds, estimated run time for 200 epochs: 2.3344 hours
# Minibatch loss at epoch 54 and iter 332499: 0.258405 and the learning rate: 0.018403
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.070%, 90.439%
# Time interval: 21.2064 seconds, estimated run time for 200 epochs: 2.3346 hours
# Minibatch loss at epoch 54 and iter 334999: 0.331603 and the learning rate: 0.018403
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.120%, 90.461%
# Time interval: 18.4294 seconds, estimated run time for 200 epochs: 2.3325 hours
# Minibatch loss at epoch 54 and iter 337499: 0.531757 and the learning rate: 0.018403
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.170%, 90.516%
# Time interval: 19.6652 seconds, estimated run time for 200 epochs: 2.3314 hours
# Minibatch loss at epoch 55 and iter 339999: 0.121966 and the learning rate: 0.017482
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.200%, 90.572%
# Time interval: 19.1276 seconds, estimated run time for 200 epochs: 2.3299 hours
# Minibatch loss at epoch 55 and iter 342499: 0.406166 and the learning rate: 0.017482
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.100%, 90.439%
# Time interval: 18.7979 seconds, estimated run time for 200 epochs: 2.3281 hours
# Minibatch loss at epoch 56 and iter 344999: 0.175867 and the learning rate: 0.017482
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 90.940%, 90.305%
# Time interval: 19.1041 seconds, estimated run time for 200 epochs: 2.3266 hours
# Minibatch loss at epoch 56 and iter 347499: 0.232928 and the learning rate: 0.017482
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.240%, 90.617%
# Time interval: 26.4982 seconds, estimated run time for 200 epochs: 2.3310 hours
# Minibatch loss at epoch 56 and iter 349999: 0.453555 and the learning rate: 0.016608
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 91.300%, 90.683%
# Time interval: 24.8267 seconds, estimated run time for 200 epochs: 2.3341 hours
# Minibatch loss at epoch 57 and iter 352499: 0.133488 and the learning rate: 0.016608
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.260%, 90.628%
# Time interval: 18.2450 seconds, estimated run time for 200 epochs: 2.3319 hours
# Minibatch loss at epoch 57 and iter 354999: 0.489516 and the learning rate: 0.016608
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.040%, 90.383%
# Time interval: 17.6881 seconds, estimated run time for 200 epochs: 2.3293 hours
# Minibatch loss at epoch 58 and iter 357499: 0.275194 and the learning rate: 0.016608
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.170%, 90.528%
# Time interval: 16.8083 seconds, estimated run time for 200 epochs: 2.3261 hours
# Minibatch loss at epoch 58 and iter 359999: 0.343599 and the learning rate: 0.015778
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.210%, 90.561%
# Time interval: 18.2552 seconds, estimated run time for 200 epochs: 2.3240 hours
# Minibatch loss at epoch 58 and iter 362499: 0.399861 and the learning rate: 0.015778
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.080%, 90.416%
# Time interval: 20.7464 seconds, estimated run time for 200 epochs: 2.3239 hours
# Minibatch loss at epoch 59 and iter 364999: 0.197938 and the learning rate: 0.015778
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.230%, 90.594%
# Time interval: 21.5112 seconds, estimated run time for 200 epochs: 2.3244 hours
# Minibatch loss at epoch 59 and iter 367499: 0.356575 and the learning rate: 0.015778
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 90.990%, 90.327%
# Time interval: 20.3610 seconds, estimated run time for 200 epochs: 2.3239 hours
# Minibatch loss at epoch 60 and iter 369999: 0.112671 and the learning rate: 0.014989
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.260%, 90.628%
# Time interval: 18.2721 seconds, estimated run time for 200 epochs: 2.3220 hours
# Minibatch loss at epoch 60 and iter 372499: 0.270245 and the learning rate: 0.014989
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.200%, 90.561%
# Time interval: 18.2377 seconds, estimated run time for 200 epochs: 2.3200 hours
# Minibatch loss at epoch 60 and iter 374999: 0.613687 and the learning rate: 0.014989
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 91.210%, 90.550%
# Time interval: 19.8230 seconds, estimated run time for 200 epochs: 2.3192 hours
# Minibatch loss at epoch 61 and iter 377499: 0.205688 and the learning rate: 0.014989
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.220%, 90.606%
# Time interval: 23.6670 seconds, estimated run time for 200 epochs: 2.3212 hours
# Minibatch loss at epoch 61 and iter 379999: 0.352729 and the learning rate: 0.014240
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.160%, 90.516%
# Time interval: 18.6143 seconds, estimated run time for 200 epochs: 2.3196 hours
# Minibatch loss at epoch 62 and iter 382499: 0.275324 and the learning rate: 0.014240
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.270%, 90.661%
# Time interval: 24.6600 seconds, estimated run time for 200 epochs: 2.3223 hours
# Minibatch loss at epoch 62 and iter 384999: 0.212615 and the learning rate: 0.014240
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.280%, 90.661%
# Time interval: 27.3231 seconds, estimated run time for 200 epochs: 2.3270 hours
# Minibatch loss at epoch 62 and iter 387499: 0.547504 and the learning rate: 0.014240
# Minibatch  train, validation and sanitized validation accuracy: 78.125%, 91.190%, 90.550%
# Time interval: 18.4190 seconds, estimated run time for 200 epochs: 2.3252 hours
# Minibatch loss at epoch 63 and iter 389999: 0.122996 and the learning rate: 0.013528
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.210%, 90.572%
# Time interval: 18.1636 seconds, estimated run time for 200 epochs: 2.3232 hours
# Minibatch loss at epoch 63 and iter 392499: 0.415654 and the learning rate: 0.013528
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.200%, 90.550%
# Time interval: 18.3708 seconds, estimated run time for 200 epochs: 2.3214 hours
# Minibatch loss at epoch 64 and iter 394999: 0.140669 and the learning rate: 0.013528
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.310%, 90.672%
# Time interval: 20.4730 seconds, estimated run time for 200 epochs: 2.3211 hours
# Minibatch loss at epoch 64 and iter 397499: 0.255266 and the learning rate: 0.013528
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.220%, 90.583%
# Time interval: 20.3537 seconds, estimated run time for 200 epochs: 2.3207 hours
# Minibatch loss at epoch 64 and iter 399999: 0.538550 and the learning rate: 0.012851
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 91.290%, 90.639%
# Time interval: 20.9319 seconds, estimated run time for 200 epochs: 2.3208 hours
# Minibatch loss at epoch 65 and iter 402499: 0.123509 and the learning rate: 0.012851
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.330%, 90.672%
# Time interval: 19.1429 seconds, estimated run time for 200 epochs: 2.3196 hours
# Minibatch loss at epoch 65 and iter 404999: 0.403874 and the learning rate: 0.012851
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.190%, 90.550%
# Time interval: 19.3573 seconds, estimated run time for 200 epochs: 2.3185 hours
# Minibatch loss at epoch 66 and iter 407499: 0.238760 and the learning rate: 0.012851
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.310%, 90.661%
# Time interval: 23.0859 seconds, estimated run time for 200 epochs: 2.3200 hours
# Minibatch loss at epoch 66 and iter 409999: 0.356229 and the learning rate: 0.012209
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.360%, 90.739%
# Time interval: 23.5094 seconds, estimated run time for 200 epochs: 2.3218 hours
# Model saved
# Minibatch loss at epoch 66 and iter 412499: 0.430617 and the learning rate: 0.012209
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.260%, 90.639%
# Time interval: 18.8285 seconds, estimated run time for 200 epochs: 2.3204 hours
# Minibatch loss at epoch 67 and iter 414999: 0.245774 and the learning rate: 0.012209
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.300%, 90.661%
# Time interval: 18.1451 seconds, estimated run time for 200 epochs: 2.3186 hours
# Minibatch loss at epoch 67 and iter 417499: 0.421245 and the learning rate: 0.012209
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.190%, 90.539%
# Time interval: 23.7329 seconds, estimated run time for 200 epochs: 2.3205 hours
# Minibatch loss at epoch 68 and iter 419999: 0.319802 and the learning rate: 0.011598
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.250%, 90.594%
# Time interval: 19.5755 seconds, estimated run time for 200 epochs: 2.3196 hours
# Minibatch loss at epoch 68 and iter 422499: 0.238910 and the learning rate: 0.011598
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.260%, 90.639%
# Time interval: 18.3904 seconds, estimated run time for 200 epochs: 2.3180 hours
# Minibatch loss at epoch 68 and iter 424999: 0.478271 and the learning rate: 0.011598
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.270%, 90.639%
# Time interval: 23.8357 seconds, estimated run time for 200 epochs: 2.3199 hours
# Minibatch loss at epoch 69 and iter 427499: 0.121591 and the learning rate: 0.011598
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.260%, 90.639%
# Time interval: 18.7729 seconds, estimated run time for 200 epochs: 2.3186 hours
# Minibatch loss at epoch 69 and iter 429999: 0.477995 and the learning rate: 0.011018
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.190%, 90.550%
# Time interval: 23.8755 seconds, estimated run time for 200 epochs: 2.3205 hours
# Minibatch loss at epoch 70 and iter 432499: 0.181719 and the learning rate: 0.011018
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.280%, 90.661%
# Time interval: 18.1224 seconds, estimated run time for 200 epochs: 2.3187 hours
# Minibatch loss at epoch 70 and iter 434999: 0.288325 and the learning rate: 0.011018
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.150%, 90.505%
# Time interval: 22.6926 seconds, estimated run time for 200 epochs: 2.3199 hours
# Minibatch loss at epoch 70 and iter 437499: 0.480989 and the learning rate: 0.011018
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 91.230%, 90.617%
# Time interval: 22.7267 seconds, estimated run time for 200 epochs: 2.3211 hours
# Minibatch loss at epoch 71 and iter 439999: 0.168571 and the learning rate: 0.010467
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.250%, 90.639%
# Time interval: 20.3047 seconds, estimated run time for 200 epochs: 2.3207 hours
# Minibatch loss at epoch 71 and iter 442499: 0.363329 and the learning rate: 0.010467
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.340%, 90.695%
# Time interval: 18.1301 seconds, estimated run time for 200 epochs: 2.3190 hours
# Minibatch loss at epoch 72 and iter 444999: 0.185058 and the learning rate: 0.010467
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.200%, 90.550%
# Time interval: 22.5160 seconds, estimated run time for 200 epochs: 2.3200 hours
# Minibatch loss at epoch 72 and iter 447499: 0.399615 and the learning rate: 0.010467
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.220%, 90.572%
# Time interval: 27.5461 seconds, estimated run time for 200 epochs: 2.3241 hours
# Minibatch loss at epoch 72 and iter 449999: 0.360045 and the learning rate: 0.009944
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.180%, 90.528%
# Time interval: 19.4336 seconds, estimated run time for 200 epochs: 2.3232 hours
# Minibatch loss at epoch 73 and iter 452499: 0.139152 and the learning rate: 0.009944
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.310%, 90.672%
# Time interval: 18.4632 seconds, estimated run time for 200 epochs: 2.3217 hours
# Minibatch loss at epoch 73 and iter 454999: 0.507875 and the learning rate: 0.009944
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.170%, 90.528%
# Time interval: 19.9639 seconds, estimated run time for 200 epochs: 2.3211 hours
# Minibatch loss at epoch 74 and iter 457499: 0.209909 and the learning rate: 0.009944
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.360%, 90.728%
# Time interval: 22.6086 seconds, estimated run time for 200 epochs: 2.3222 hours
# Minibatch loss at epoch 74 and iter 459999: 0.179811 and the learning rate: 0.009447
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.340%, 90.717%
# Time interval: 23.4569 seconds, estimated run time for 200 epochs: 2.3237 hours
# Minibatch loss at epoch 74 and iter 462499: 0.432478 and the learning rate: 0.009447
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.330%, 90.706%
# Time interval: 20.4329 seconds, estimated run time for 200 epochs: 2.3234 hours
# Minibatch loss at epoch 75 and iter 464999: 0.153255 and the learning rate: 0.009447
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.170%, 90.516%
# Time interval: 20.5604 seconds, estimated run time for 200 epochs: 2.3232 hours
# Minibatch loss at epoch 75 and iter 467499: 0.439674 and the learning rate: 0.009447
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.390%, 90.772%
# Time interval: 18.5128 seconds, estimated run time for 200 epochs: 2.3218 hours
# ...
# Time interval: 18.4183 seconds, estimated run time for 200 epochs: 2.6619 hours
# Minibatch loss at epoch 161 and iter 1002499: 0.115914 and the learning rate: 0.000592
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.440%, 90.795%
# Time interval: 26.4473 seconds, estimated run time for 200 epochs: 2.6626 hours
# Minibatch loss at epoch 161 and iter 1004999: 0.454686 and the learning rate: 0.000592
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.420%, 90.772%
# Time interval: 25.1519 seconds, estimated run time for 200 epochs: 2.6629 hours
# Minibatch loss at epoch 162 and iter 1007499: 0.156537 and the learning rate: 0.000592
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.440%, 90.795%
# Time interval: 23.3775 seconds, estimated run time for 200 epochs: 2.6628 hours
# Minibatch loss at epoch 162 and iter 1009999: 0.264501 and the learning rate: 0.000562
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.400%, 90.750%
# Time interval: 18.5503 seconds, estimated run time for 200 epochs: 2.6613 hours
# Minibatch loss at epoch 162 and iter 1012499: 0.370404 and the learning rate: 0.000562
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.400%, 90.750%
# Time interval: 19.2405 seconds, estimated run time for 200 epochs: 2.6600 hours
# Minibatch loss at epoch 163 and iter 1014999: 0.163334 and the learning rate: 0.000562
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.440%, 90.795%
# Time interval: 24.8112 seconds, estimated run time for 200 epochs: 2.6602 hours
# Minibatch loss at epoch 163 and iter 1017499: 0.389433 and the learning rate: 0.000562
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.440%, 90.795%
# Time interval: 20.1055 seconds, estimated run time for 200 epochs: 2.6592 hours
# Minibatch loss at epoch 164 and iter 1019999: 0.218774 and the learning rate: 0.000534
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.410%, 90.761%
# Time interval: 31.8691 seconds, estimated run time for 200 epochs: 2.6613 hours
# Minibatch loss at epoch 164 and iter 1022499: 0.153387 and the learning rate: 0.000534
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.390%, 90.739%
# Time interval: 21.4469 seconds, estimated run time for 200 epochs: 2.6607 hours
# Minibatch loss at epoch 164 and iter 1024999: 0.762806 and the learning rate: 0.000534
# Minibatch  train, validation and sanitized validation accuracy: 78.125%, 91.370%, 90.717%
# Time interval: 18.8881 seconds, estimated run time for 200 epochs: 2.6593 hours
# Minibatch loss at epoch 165 and iter 1027499: 0.151472 and the learning rate: 0.000534
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.390%, 90.739%
# Time interval: 18.5657 seconds, estimated run time for 200 epochs: 2.6578 hours
# Minibatch loss at epoch 165 and iter 1029999: 0.419853 and the learning rate: 0.000508
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.430%, 90.795%
# Time interval: 21.7868 seconds, estimated run time for 200 epochs: 2.6573 hours
# Minibatch loss at epoch 166 and iter 1032499: 0.148691 and the learning rate: 0.000508
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.390%, 90.750%
# Time interval: 35.0950 seconds, estimated run time for 200 epochs: 2.6603 hours
# Minibatch loss at epoch 166 and iter 1034999: 0.306275 and the learning rate: 0.000508
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.400%, 90.761%
# Time interval: 19.1867 seconds, estimated run time for 200 epochs: 2.6590 hours
# Minibatch loss at epoch 166 and iter 1037499: 0.460173 and the learning rate: 0.000508
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.420%, 90.772%
# Time interval: 25.3207 seconds, estimated run time for 200 epochs: 2.6594 hours
# Minibatch loss at epoch 167 and iter 1039999: 0.077350 and the learning rate: 0.000482
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.440%, 90.795%
# Time interval: 22.8369 seconds, estimated run time for 200 epochs: 2.6591 hours
# Minibatch loss at epoch 167 and iter 1042499: 0.429476 and the learning rate: 0.000482
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.450%, 90.806%
# Time interval: 25.8479 seconds, estimated run time for 200 epochs: 2.6596 hours
# Minibatch loss at epoch 168 and iter 1044999: 0.226809 and the learning rate: 0.000482
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.460%, 90.817%
# Time interval: 20.3275 seconds, estimated run time for 200 epochs: 2.6586 hours
# Minibatch loss at epoch 168 and iter 1047499: 0.262203 and the learning rate: 0.000482
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.410%, 90.761%
# Time interval: 26.2226 seconds, estimated run time for 200 epochs: 2.6592 hours
# Minibatch loss at epoch 168 and iter 1049999: 0.375851 and the learning rate: 0.000458
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.440%, 90.795%
# Time interval: 23.1496 seconds, estimated run time for 200 epochs: 2.6590 hours
# Minibatch loss at epoch 169 and iter 1052499: 0.137918 and the learning rate: 0.000458
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.420%, 90.772%
# Time interval: 20.7008 seconds, estimated run time for 200 epochs: 2.6582 hours
# Minibatch loss at epoch 169 and iter 1054999: 0.350623 and the learning rate: 0.000458
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.450%, 90.806%
# Time interval: 29.7010 seconds, estimated run time for 200 epochs: 2.6597 hours
# Minibatch loss at epoch 170 and iter 1057499: 0.266451 and the learning rate: 0.000458
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.460%, 90.817%
# Time interval: 24.9532 seconds, estimated run time for 200 epochs: 2.6600 hours
# Minibatch loss at epoch 170 and iter 1059999: 0.241547 and the learning rate: 0.000435
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.440%, 90.795%
# Time interval: 21.1853 seconds, estimated run time for 200 epochs: 2.6592 hours
# Minibatch loss at epoch 170 and iter 1062499: 0.477523 and the learning rate: 0.000435
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 91.460%, 90.828%
# Time interval: 20.1107 seconds, estimated run time for 200 epochs: 2.6582 hours
# Minibatch loss at epoch 171 and iter 1064999: 0.078100 and the learning rate: 0.000435
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.410%, 90.761%
# Time interval: 24.1683 seconds, estimated run time for 200 epochs: 2.6583 hours
# Minibatch loss at epoch 171 and iter 1067499: 0.406366 and the learning rate: 0.000435
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.460%, 90.828%
# Time interval: 23.2646 seconds, estimated run time for 200 epochs: 2.6581 hours
# Minibatch loss at epoch 172 and iter 1069999: 0.170662 and the learning rate: 0.000413
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.430%, 90.784%
# Time interval: 29.7157 seconds, estimated run time for 200 epochs: 2.6596 hours
# Minibatch loss at epoch 172 and iter 1072499: 0.180434 and the learning rate: 0.000413
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.390%, 90.739%
# Time interval: 31.5023 seconds, estimated run time for 200 epochs: 2.6616 hours
# Minibatch loss at epoch 172 and iter 1074999: 0.437623 and the learning rate: 0.000413
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.410%, 90.772%
# Time interval: 26.9974 seconds, estimated run time for 200 epochs: 2.6624 hours
# Minibatch loss at epoch 173 and iter 1077499: 0.132718 and the learning rate: 0.000413
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.400%, 90.750%
# Time interval: 20.1645 seconds, estimated run time for 200 epochs: 2.6614 hours
# Minibatch loss at epoch 173 and iter 1079999: 0.449231 and the learning rate: 0.000393
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.420%, 90.784%
# Time interval: 27.4356 seconds, estimated run time for 200 epochs: 2.6623 hours
# Minibatch loss at epoch 174 and iter 1082499: 0.179975 and the learning rate: 0.000393
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.430%, 90.806%
# Time interval: 31.4601 seconds, estimated run time for 200 epochs: 2.6642 hours
# Minibatch loss at epoch 174 and iter 1084999: 0.278807 and the learning rate: 0.000393
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.430%, 90.784%
# Time interval: 26.9500 seconds, estimated run time for 200 epochs: 2.6650 hours
# Minibatch loss at epoch 174 and iter 1087499: 0.614092 and the learning rate: 0.000393
# Minibatch  train, validation and sanitized validation accuracy: 78.125%, 91.400%, 90.761%
# Time interval: 26.4407 seconds, estimated run time for 200 epochs: 2.6656 hours
# Minibatch loss at epoch 175 and iter 1089999: 0.101976 and the learning rate: 0.000373
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.410%, 90.761%
# Time interval: 22.3419 seconds, estimated run time for 200 epochs: 2.6652 hours
# Minibatch loss at epoch 175 and iter 1092499: 0.372885 and the learning rate: 0.000373
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.460%, 90.817%
# Time interval: 23.5692 seconds, estimated run time for 200 epochs: 2.6651 hours
# Minibatch loss at epoch 176 and iter 1094999: 0.387943 and the learning rate: 0.000373
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.460%, 90.817%
# Time interval: 26.9485 seconds, estimated run time for 200 epochs: 2.6658 hours
# Minibatch loss at epoch 176 and iter 1097499: 0.242382 and the learning rate: 0.000373
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.380%, 90.728%
# Time interval: 33.7301 seconds, estimated run time for 200 epochs: 2.6683 hours
# Minibatch loss at epoch 176 and iter 1099999: 0.536017 and the learning rate: 0.000354
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.430%, 90.795%
# Time interval: 25.2009 seconds, estimated run time for 200 epochs: 2.6686 hours
# Minibatch loss at epoch 177 and iter 1102499: 0.123448 and the learning rate: 0.000354
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.390%, 90.739%
# Time interval: 22.3897 seconds, estimated run time for 200 epochs: 2.6682 hours
# Minibatch loss at epoch 177 and iter 1104999: 0.353812 and the learning rate: 0.000354
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.430%, 90.795%
# Time interval: 23.3058 seconds, estimated run time for 200 epochs: 2.6680 hours
# Minibatch loss at epoch 178 and iter 1107499: 0.289798 and the learning rate: 0.000354
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.410%, 90.761%
# Time interval: 23.3646 seconds, estimated run time for 200 epochs: 2.6678 hours
# Minibatch loss at epoch 178 and iter 1109999: 0.174442 and the learning rate: 0.000337
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.360%, 90.706%
# Time interval: 30.3354 seconds, estimated run time for 200 epochs: 2.6694 hours
# Minibatch loss at epoch 178 and iter 1112499: 0.403281 and the learning rate: 0.000337
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.470%, 90.828%
# Time interval: 20.5517 seconds, estimated run time for 200 epochs: 2.6686 hours
# Minibatch loss at epoch 179 and iter 1114999: 0.164644 and the learning rate: 0.000337
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.380%, 90.728%
# Time interval: 19.0957 seconds, estimated run time for 200 epochs: 2.6673 hours
# Minibatch loss at epoch 179 and iter 1117499: 0.300387 and the learning rate: 0.000337
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.430%, 90.784%
# Time interval: 21.6523 seconds, estimated run time for 200 epochs: 2.6667 hours
# Minibatch loss at epoch 180 and iter 1119999: 0.236915 and the learning rate: 0.000320
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.380%, 90.728%
# Time interval: 20.7743 seconds, estimated run time for 200 epochs: 2.6659 hours
# Minibatch loss at epoch 180 and iter 1122499: 0.145184 and the learning rate: 0.000320
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.370%, 90.717%
# Time interval: 23.8787 seconds, estimated run time for 200 epochs: 2.6659 hours
# Minibatch loss at epoch 180 and iter 1124999: 0.419932 and the learning rate: 0.000320
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.450%, 90.806%
# Time interval: 18.2258 seconds, estimated run time for 200 epochs: 2.6645 hours
# Minibatch loss at epoch 181 and iter 1127499: 0.128200 and the learning rate: 0.000320
# Minibatch  train, validation and sanitized validation accuracy: 96.875%, 91.360%, 90.706%
# Time interval: 20.1558 seconds, estimated run time for 200 epochs: 2.6636 hours
# Minibatch loss at epoch 181 and iter 1129999: 0.345548 and the learning rate: 0.000304
# Minibatch  train, validation and sanitized validation accuracy: 84.375%, 91.410%, 90.761%
# Time interval: 22.2529 seconds, estimated run time for 200 epochs: 2.6631 hours
# Minibatch loss at epoch 182 and iter 1132499: 0.149083 and the learning rate: 0.000304
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.410%, 90.761%
# Time interval: 20.6360 seconds, estimated run time for 200 epochs: 2.6623 hours
# Minibatch loss at epoch 182 and iter 1134999: 0.158705 and the learning rate: 0.000304
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.390%, 90.739%
# Time interval: 19.0105 seconds, estimated run time for 200 epochs: 2.6611 hours
# Minibatch loss at epoch 182 and iter 1137499: 0.444048 and the learning rate: 0.000304
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.400%, 90.761%
# Time interval: 21.0514 seconds, estimated run time for 200 epochs: 2.6604 hours
# Minibatch loss at epoch 183 and iter 1139999: 0.165029 and the learning rate: 0.000289
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.390%, 90.739%
# Time interval: 18.2558 seconds, estimated run time for 200 epochs: 2.6590 hours
# Minibatch loss at epoch 183 and iter 1142499: 0.316632 and the learning rate: 0.000289
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.410%, 90.761%
# Time interval: 20.2332 seconds, estimated run time for 200 epochs: 2.6581 hours
# Minibatch loss at epoch 184 and iter 1144999: 0.201569 and the learning rate: 0.000289
# Minibatch  train, validation and sanitized validation accuracy: 90.625%, 91.410%, 90.772%
# Time interval: 21.8213 seconds, estimated run time for 200 epochs: 2.6576 hours
# Minibatch loss at epoch 184 and iter 1147499: 0.311700 and the learning rate: 0.000289
# Minibatch  train, validation and sanitized validation accuracy: 87.500%, 91.400%, 90.750%
# Time interval: 24.6766 seconds, estimated run time for 200 epochs: 2.6578 hours
# Minibatch loss at epoch 184 and iter 1149999: 0.551594 and the learning rate: 0.000274
# Minibatch  train, validation and sanitized validation accuracy: 81.250%, 91.440%, 90.806%
# Time interval: 19.5906 seconds, estimated run time for 200 epochs: 2.6567 hours
# Minibatch loss at epoch 185 and iter 1152499: 0.157036 and the learning rate: 0.000274
# Minibatch  train, validation and sanitized validation accuracy: 93.750%, 91.390%, 90.739%
# Time interval: 21.4390 seconds, estimated run time for 200 epochs: 2.6561 hours
# Final Test accuracy: 96.4%
# Test accuracy with the best model: 96.440%
# Sanitized test accuracy with the best model: 96.004%
# Total run time 184.0799 minutes

# %% [markdown]
# Results:
#
# Final Test accuracy: 96.4%
#
# Test accuracy with the best model: 96.440%
#
# Sanitized test accuracy with the best model: 96.004%
#
# Total run time 184.0799 minutes
#
# *I trained this model using the GPU (Nvidia Geforce GT 650M) on my laptop.*

# %% [markdown]
# ---
